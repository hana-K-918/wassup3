# %%
import requests
from bs4 import BeautifulSoup

# %%
PATH = 'https://finance.naver.com/'
resp = requests.get(PATH)
resp
# Out:
# <Response [200]>

# %%
src = resp.text

# %%
soup = BeautifulSoup(src, 'lxml')
print(soup)
# Out:
# <html lang="ko">
# <head>
# <title>네이버페이 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="네이버페이 증권" name="apple-mobile-web-app-title"/>
# <meta content="네이버페이 증권" property="og:title"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="https://finance.naver.com" property="og:url"/>
# <meta content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="네이버페이 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240618155848/css/finance_header.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240618155848/css/finance.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20240618155848/css/newstock3.css" rel="stylesheet" type="text/css"/>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240618155848/js/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240618155848/js/release/common.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240618155848/js/jindoComponent/jindo.Component.1.0.3.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240618155848/js/nhn.autocomplete.stock.js" type="text/javascript"></script>
# <script>
# 	var ieVersion = (function () {
#         var version = -1;
#         if (
#           navigator.appName == 'Microsoft Internet Explorer' &&
#           navigator.userAgent.toLowerCase().indexOf('msie') != -1 &&
#           new RegExp('MSIE ([0-9]{1,}[\./0-9]{0,})').exec(navigator.userAgent) != null
#         ) {
#           version = parseInt(RegExp.$1);
#         }
#         return version;
#       })();
# </script>
# <!-- smart channel 광고 -->
# <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">
# </script>
# <script type="text/javascript">
# 		(function(){
# 			if (ieVersion === -1 || ieVersion > 10) {
# 				window.gladsdk = window.gladsdk || { cmd: [] };
#
# 				gladsdk.cmd.push(function() {
# 						gladsdk.defineAdSlot({
# 							adUnitId: "p_new_stock",
# 							adSlotElementId: "_SmartChannelTopBanner",
# 							uct: "KR",
# 							customParam: {
# 								calp:
#
#
#
#
#
#
# 									"home"
# 							},
# 						});
#
#
#
# 						gladsdk.addEventListener(gladsdk.event.AD_LOADED, function(ad) {
# 							//console.log(gladsdk.event.AD_LOADED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.AD_CLICKED, function(ad) {
# 							//console.log(gladsdk.event.AD_CLICKED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.AD_IMPRESSED, function(ad) {
# 							//console.log(gladsdk.event.AD_IMPRESSED);
# 						});
# 						gladsdk.addEventListener(gladsdk.event.ERROR, function(ad, error) {
# 							//TODO: 오류 로깅처리
# 							//console.log(gladsdk.event.ERROR);
# 						});
# 					});
# 			}
# 		})();
# 	</script>
# <link href="https://ssl.pstatic.net/imgstock/favi/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
#     (function(){
# 		document.write(
# 				[
# 					'<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/imgstock/favi/favicon-180x180.png"/>',
# 					'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>',
# 					'<link rel="icon" type="image/png" sizes="16x16" href="https://ssl.pstatic.net/imgstock/favi/favicon-16x16.png"/>',
# 					'<link rel="icon" type="image/png" sizes="32x32" href="https://ssl.pstatic.net/imgstock/favi/favicon-32x32.png"/>',
# 					'<link rel="icon" type="image/png" sizes="96x96" href="https://ssl.pstatic.net/imgstock/favi/favicon-96x96.png"/>',
# 					'<link rel="icon" type="image/png" sizes="192x192" href="https://ssl.pstatic.net/imgstock/favi/favicon-192x192.png"/>'
# 				]
# 			.join('\n')
# 		);
#     })();
#     </script>
# </head>
# <body onload="getGNB();">
# <script type="text/javascript">
# 	var nclk_evt = 3;
# 	nclk_do();
# </script>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var nsc="finance.home";
#
#
# var ccsrv="cc.naver.com";
#
#
#
#
# 	var gnb_service='finance';
#
#
#
# var gnb_logout=document.URL; //GNB에서 로그아웃 후 redirect 될 URL
# var gnb_searchbox='off'; //미니 검색창을 on 할지 off 할지. default는 off
# var gnb_shortnick='off'; //닉네임 말줄임(10자)을 on할지 off 할지. default는 off.
#
#
# var gnb_naverme_layer_open_callback = function(){
# 	   var naverLayerSize = gnbNaverMeLayer.getLayerSize();
#
# 		var me_layers = document.getElementById("me_layers");
# 		me_layers.width=naverLayerSize.width;
# 		me_layers.height=naverLayerSize.height;};
#
# var gnb_naverme_layer_close_callback = function(){
#
# 			var me_layers = document.getElementById("me_layers");
# 			me_layers.width="0";
# 			me_layers.height="0";};
# </script>
# <div id="u_skip">
# <a href="#menu" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#start" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div id="header">
# <div class="header_area">
# <div class="header_inner">
# <div class="logo_area">
# <h1 class="service">
# <a class="logo_link" href="https://www.naver.com/" onclick="clickcr(this, 'STA.naver', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 22 22" width="22" xmlns="http://www.w3.org/2000/svg">
# <path d="M22 11C22 13.1756 21.3549 15.3023 20.1462 17.1113C18.9375 18.9202 17.2195 20.3301 15.2095 21.1627C13.1995 21.9952 10.9878 22.2131 8.85401 21.7886C6.72022 21.3642 4.76021 20.3166 3.22183 18.7782C1.68345 17.2398 0.635805 15.2798 0.211368 13.146C-0.213069 11.0122 0.00476298 8.80047 0.837327 6.79048C1.66989 4.78049 3.07979 3.06253 4.88873 1.85383C6.69768 0.645137 8.82441 0 11 0C13.9174 0 16.7153 1.15893 18.7782 3.22183C20.8411 5.28473 22 8.08262 22 11ZM12.8398 5.83V11.3602L8.98976 5.83H5.83V16.1838H9.1575V10.637L13.0075 16.17H16.1783V5.83H12.8398Z" fill="#000"></path>
# </svg>
# <span class="blind">네이버</span>
# </a>
# <a class="logo_link" href="https://new-m.pay.naver.com/" onclick="clickcr(this, 'STA.pay', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 37 22" width="37" xmlns="http://www.w3.org/2000/svg">
# <path d="M34.4319 5.21944L31.3913 12.1478L27.9518 5.21944H25.3072L30.1783 14.8317L28.1703 19.3358H30.7384L37 5.2331L34.4319 5.21944ZM23.6171 15.9331H21.1037V14.9328C20.1894 15.7342 19.0108 16.1685 17.7953 16.1518C14.7901 16.1518 12.4379 13.692 12.4379 10.5763C12.4379 7.46057 14.7874 5.00079 17.7953 5.00079C19.0104 4.9833 20.189 5.41657 21.1037 6.21701V5.21944H23.6171V15.9331ZM21.3987 10.5899C21.3987 8.57019 19.9891 7.03694 18.1204 7.03694C16.2517 7.03694 14.842 8.57019 14.842 10.5899C14.842 12.6097 16.249 14.1429 18.1204 14.1429C19.9918 14.1429 21.3987 12.596 21.3987 10.5899ZM0.00819554 19.3358H2.63088V15.023C3.52823 15.7695 4.66309 16.1699 5.83001 16.1518C8.83516 16.1518 11.1901 13.692 11.1901 10.5763C11.1901 7.46057 8.83789 5.00079 5.83001 5.00079C4.61166 4.9789 3.42899 5.4126 2.51341 6.21701V5.21944H0L0.00819554 19.3358ZM5.51856 7.03694C7.38722 7.03694 8.79691 8.57019 8.79691 10.5899C8.79691 12.6097 7.38722 14.1429 5.51856 14.1429C3.6499 14.1429 2.24021 12.6097 2.24021 10.5899C2.24021 8.57019 3.63351 7.03694 5.51856 7.03694Z" fill="#000"></path>
# </svg>
# <span class="blind">페이</span>
# </a>
# <a class="logo_link" href="/" onclick="clickcr(this, 'STA.finance', '', '', event);">
# <svg fill="none" height="22" viewbox="0 0 34 22" width="34" xmlns="http://www.w3.org/2000/svg">
# <path d="M2.43006 8.88998L1.85406 6.99998C5.29206 6.31598 7.00206 5.34398 7.45206 4.31798H2.71806V2.35598H14.3641V4.31798H9.75606C9.70206 4.65998 9.61206 4.98398 9.46806 5.28998L15.2101 6.98198L14.4901 8.88998L8.02806 6.92798C6.84006 7.75598 5.00406 8.40398 2.43006 8.88998ZM0.612061 11.5V9.53798H16.4521V11.5H0.612061ZM6.53406 12.796H10.5301C13.2301 12.796 14.7961 14.128 14.7961 15.91C14.7961 17.71 13.2301 19.024 10.5301 19.024H6.53406C3.85206 19.024 2.28606 17.71 2.28606 15.91C2.28606 14.128 3.85206 12.796 6.53406 12.796ZM6.96606 17.044H10.1161C11.7901 17.044 12.4921 16.594 12.4921 15.892C12.4921 15.19 11.7901 14.776 10.1161 14.776H6.96606C5.29206 14.776 4.57206 15.19 4.57206 15.892C4.57206 16.594 5.29206 17.044 6.96606 17.044Z" fill="#000"></path>
# <path d="M25.1904 13.354V11.536H29.4564V2.03198H31.7604V15.334H29.4564V13.354H25.1904ZM21.3384 10.564C20.9244 10.582 20.5464 10.582 20.1684 10.582H17.4504L17.3604 8.61998H20.3844C21.5004 8.61998 22.9584 8.56598 24.4884 8.45798C24.7224 6.99998 24.8484 5.63198 24.8664 4.62398H18.4404V2.66198H27.0984V3.56198C27.0984 5.16398 26.9724 6.76598 26.7564 8.25998L28.2684 8.09798L28.5024 10.006C26.9724 10.222 25.2264 10.384 23.5704 10.474C23.4984 11.5 23.3904 12.562 23.2644 13.714L21.0684 13.588C21.1764 12.508 21.2664 11.536 21.3384 10.564ZM22.4724 14.254V16.756H32.3724V18.844H20.1684V14.254H22.4724Z" fill="#000"></path>
# </svg>
# <span class="blind">증권</span>
# </a>
# </h1>
# </div>
# <div class="right_area">
# <div class="search_area">
# <form action="/search/search.naver" method="get" name="search" onsubmit="return delayed_submit(this)" style="margin:0; padding:0;">
# <label class="blind" for="stock_items">증권 종목명·지수명 검색</label>
# <input accesskey="s" autocomplete="off" class="search_input" id="stock_items" name="query" placeholder="종목명·지수명 입력" title="종목명·지수명 검색" type="text"/>
# <input id="_endUrl" name="endUrl" type="hidden" value=""/>
# <button class="search_button" onclick="clickcr(this, 'STA.search', '', '', event);" type="button">
# <svg fill="none" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M6.9999 2.59996C4.56985 2.59996 2.5999 4.56991 2.5999 6.99996C2.5999 9.43002 4.56985 11.4 6.9999 11.4C9.42996 11.4 11.3999 9.43002 11.3999 6.99996C11.3999 4.56991 9.42996 2.59996 6.9999 2.59996ZM1.3999 6.99996C1.3999 3.90717 3.90711 1.39996 6.9999 1.39996C10.0927 1.39996 12.5999 3.90717 12.5999 6.99996C12.5999 10.0928 10.0927 12.6 6.9999 12.6C3.90711 12.6 1.3999 10.0928 1.3999 6.99996Z" fill="#404048" fill-rule="evenodd"></path>
# <path clip-rule="evenodd" d="M10.2421 10.2424C10.4765 10.0081 10.8564 10.0081 11.0907 10.2424L14.424 13.5758C14.6583 13.8101 14.6583 14.19 14.424 14.4243C14.1897 14.6586 13.8098 14.6586 13.5755 14.4243L10.2421 11.091C10.0078 10.8567 10.0078 10.4768 10.2421 10.2424Z" fill="#404048" fill-rule="evenodd"></path>
# </svg>
# <span class="blind">검색</span>
# </button>
# <div class="auto_area">
# <span class="blind">자동완성</span>
# <div id="autoFrame" style="display: none;">
# <div class="wrap" id="atcmp" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <ul class="_resultBox">
# <li>
# <a class="_au_real_list" href="#" onclick="clickcr(this, 'AUT.list', '', '', event); return false;">
# <span class="num _au_real_list">@code@</span>
# <span class="_au_real_list">@txt@</span>
# <span class="type _au_real_list">@market@</span>
# </a>
# <div class="_au_full" style="display:none">@full_txt@</div>
# <div class="_au_code" style="display:none">@in_code@</div>
# <div class="_au_name" style="display:none">@in_name@</div>
# <div class="_au_link" style="display:none">@in_link@</div>
# <div class="_au_market" style="display:none">@in_market@</div>
# </li>
# </ul>
# </div>
# </div>
# <!-- 현재 자동완성 기능을 사용하고 계십니다 -->
# <div class="wrap" id="atcmpIng" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <p class="msg">
# 												현재 자동완성 기능을 사용하고 계십니다.
# 											</p>
# </div>
# </div>
# </div>
# <!--// 현재 자동완성 기능을 사용하고 계십니다 -->
# <!-- 자동완성 기능이 활성화 -->
# <div class="wrap" id="atcmpStart" style="display:none;">
# <div class="wrap_in">
# <div class="words">
# <p class="msg">
# 												자동완성 기능이 활성화되었습니다.
# 											</p>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# <div class="gnb_area">
# <div id="gnb">
# <script charset="EUC-KR" type="text/javascript">
# 							var gnb_service = "finance";
# 							var gnb_template = location.protocol === "http:" ? "gnb_quirks_euckr" : "gnb_utf8" ;
# 							var gnb_logout=encodeURIComponent(location.href);
# 							var gnb_brightness = 1;
# 							var gnb_one_naver = 0;
# 						</script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn?20240622" type="text/javascript">
# </script>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div id="menu">
# <ul class="menu">
# <li class="m1 first on"><a href="/" onclick="clickcr(this, 'LNB.home', '', '', event);"><span class="tx">증권 홈</span><span class="blind">선택됨</span></a></li>
# <li class="m2"><a href="/sise/" onclick="clickcr(this, 'LNB.sise', '', '', event);"><span class="tx">국내증시</span></a></li>
# <li class="m3"><a href="/world/" onclick="clickcr(this, 'LNB.world', '', '', event);"><span class="tx">해외증시</span></a></li>
# <li class="m4"><a href="/marketindex/" onclick="clickcr(this, 'LNB.market', '', '', event);"><span class="tx">시장지표</span></a></li>
# <li class="m6"><a href="/research/" onclick="clickcr(this, 'LNB.research', '', '', event);"><span class="tx">리서치</span></a></li>
# <li class="m7"><a href="/news/"><span class="tx">뉴스</span></a></li>
# <li class="m8"><a href="/mystock/" onclick="clickcr(this, 'LNB.mystock', '', '', event);"><span class="tx">MY</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <script type="text/JavaScript">
# 		/* lcs 집계 */
#         ;(function(){
#             var eventType = "onpageshow" in window ? "pageshow" : "load";
#             jindo.$Fn(function(){
#                 lcs_do();
#             }).attach(window, eventType);
#         })();
#
# 		/* 검색 자동완성 [ 인자1 : 검색input의 ID, 인자2 : iframe 태그 ID ]   */
# 		// AutoComplete 생성
# 		var acDomain = "ac.stock.naver.com";
# 		if (location.hostname.indexOf("staging-") > -1) {
# 			acDomain = "staging-" + acDomain;
# 		} else if (location.hostname.indexOf("test-") > -1) {
# 			acDomain = "test-" + acDomain;
# 		} else if (location.hostname.indexOf("dev-") > -1 || location.hostname.indexOf("localhost") > -1 || location.hostname.indexOf("local-") > -1) {
# 			acDomain = "dev-" + acDomain;
# 		}
#
#         var acUrl = "https://" + acDomain + "/ac";
#
# 		smartSearch = new nhn.Autocomplete(
# 			// InputManager 생성
# 			new nhn.AcInputManager(jindo.$("stock_items")),
# 			// DataManager 생성
# 			new nhn.AcDataManager(acUrl, "xhr", "get", {}),
# 			// ViewManager 생성
# 			new nhn.AcStockViewManager(jindo.$("autoFrame"), jindo.$("nautocomplete"), {
#                                         strMax: 200,
#                                         listMax: [7, 2, 2],
#                                         aRedirectUrl : [
# 										"https://" + window.location.hostname,
#                             			"https://finance.naver.com",
#                             			"https://finance.naver.com"]}),
# 			// Autocomplete Option
#             {formId:"search", cookieDomain:location.hostname, cookieName:"NaverCommonStock_disable"});
#
# 			smartSearch.attach({
# 	            onFocus: function () {
# 	                var weInput = jindo.$Element('stock_items');
# 	                if (weInput && weInput.hasClass("snb_default")) {
# 	                        weInput.text("");
# 	                        weInput.removeClass('snb_default');
# 	                }
# 	            }
# 	        });
#
# 		/* 통합검색  start ----->  */
# 		var sSearchHintText = '종목명·지수명·환율명·원자재명 입력';
# 		function itegrationSearch() {
# 			var query = jindo.$('stock_items').value;
#
# 			if ( query == ''  || encodeURIComponent(query) == encodeURIComponent(sSearchHintText))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
#
#             var url = location.protocol + "//search.naver.com/search.naver?sm=sta_hty.finance&where=nexearch&ie=UTF8&query=" + encodeURIComponent(query);
#             window.open(url, "_blank");
#
# 			return false;
# 		}
#
# 		function delayed_submit(object) {
# 			if (navigator.userAgent.indexOf('MSIE') == -1) {
# 				window.setTimeout(function() {stock_search(object)}, 300);
# 			} else {
# 				stock_search(object);
# 			}
# 			return false;
# 		}
#
# 		function stock_search (object)
# 		{
# 			// endUrl check
# 			if (object.endUrl.value) {
# 				location.href = object.endUrl.value;
# 				return;
# 			}
#
# 			// query check
# 			query = object.query.value.replace(/^\s*/,'').replace(/\s*$/,'');	// trim
# 			object.query.value=query;
#
# 			if ( query == '' || query == sSearchHintText.replace(/^\s*/,'').replace(/\s*$/,''))
# 			{
# 				alert ( '검색어를 입력해 주세요.' );
# 				return;
# 			}
# 			else {
# 				object.submit();
# 			}
# 		}
# 		/* <---------- 통합검색  end */
#
# 		function popup()
# 		{
# 			win = window.open('/template/group_limit_pop.jsp','finan_popup','width=569 height=278 scrollbars=no status=no');
# 			win.focus();
# 		}
# 	</script>
# <iframe frameborder="0" height="0" id="me_layers" name="test" scrolling="no" style="display:block;top: 22px; right: 209px; position: absolute; z-index: 15;" title="네이버미 영역" width="0"></iframe>
# </div>
# <div id="wrap">
# <hr/>
# <div class="blind" id="start"><strong name="start">본문시작</strong></div>
# <dl class="blind">
# <dt>오늘의 코스피/코스닥 지수</dt>
# <dd>2024년 06월 21일 장마감</dd>
# <dd>코스피 지수 2,784.26 전일대비 하락 23.37 마이너스 0.83 퍼센트</dd>
# <dd>코스닥 지수 852.67 전일대비 하락 4.84 마이너스 0.56 퍼센트</dd>
# </dl>
# <div class="home_spot view_on">
# <div class="bx_spot">
# <div class="tab_spot tab2" id="tab_search">
# <ul>
# <li><a href="#" onclick="javascript:showMainRecentMyStockSearchStock('tab_search', 'tab_spot tab1', '000000', 'recent');clickcr(this, 'mys.recent', '', '', event);return false;"><span>최근조회종목</span></a></li>
# <li><a href="#" onclick="javascript:showMainRecentMyStockSearchStock('tab_search', 'tab_spot tab2', '000000', 'mystock');clickcr(this, 'mys.interest', '', '', event);return false;"><span>MY STOCK</span></a></li>
# </ul>
# </div>
# <div class="section_tab" id="recent_search_tab">
# <strong class="blind" id="recent_mystock_blind">최근 조회종목 리스트</strong>
# <ul class="tab_list">
# </ul>
# </div>
# <input alt="닫기" class="btn_spot" onclick="clickcr(this, (jindo.$Element('tab_search').hasClass('tab1') ? 'mys*r.close' : 'mys*i.close'), '', '', event);" src="https://ssl.pstatic.net/static/nfinance/btn_spot_close.gif" style="display:none" type="image"/>
# <input alt="펼치기" class="btn_spot" onclick="clickcr(this, (jindo.$Element('tab_search').hasClass('tab1') ? 'mys*r.open' : 'mys*i.open'), '', '', event);" src="https://ssl.pstatic.net/static/nfinance/btn_spot_open.gif" style="display:none" type="image"/>
# </div>
# </div>
# <div class="home" id="container">
# <div id="content">
# <div class="article">
# <div class="section">
# <div class="news_area _replaceNewsLink">
# <div class="section_strategy">
# <h2 class="h_strategy"><span>주요뉴스</span></h2>
# <ul>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=243&amp;article_id=0000060980" onclick="clickcr(this, 'tdn.list', '243_0000060980', '0', event);">국내 증시 대신 해외 주식 택하는 개미들... 해외주식 보관액 역대 최대 기록</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=011&amp;article_id=0004356599" onclick="clickcr(this, 'tdn.list', '011_0004356599', '1', event);">'AI 황제株' 엔비디아 이틀 연속 3%대 하락…무슨 일?</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=421&amp;article_id=0007617224" onclick="clickcr(this, 'tdn.list', '421_0007617224', '2', event);">연중 최고치 기록한 '빚투'…돈 빌려 대왕고래·이혼 테마주 산 개미들</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=008&amp;article_id=0005054029" onclick="clickcr(this, 'tdn.list', '008_0005054029', '3', event);">증시 출사표 백종원 '더본'…풀무원·동원 vs 교촌, 어느 곳과 닮았나?</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=009&amp;article_id=0005322999" onclick="clickcr(this, 'tdn.list', '009_0005322999', '4', event);">“돈도 안되는 4등, 왜 하겠어”…이통사 또 만들겠다는 정부, 헛다리 짚었다 [나기자의 데이터로 세상읽기]</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=018&amp;article_id=0005770929" onclick="clickcr(this, 'tdn.list', '018_0005770929', '5', event);">‘시누이 지분 매도’ 마저 소화해버린 ‘불닭 열풍’[증시 핫피플]</a></span>
# </li>
# </ul>
# <a class="btn_more" href="/news/mainnews.naver" onclick="clickcr(this, 'tdn.more', '', '', event);"><em class="btn_more4"><span class="blind">주요뉴스 더보기</span></em></a>
# </div>
# </div>
# <div class="section_sise_top">
# <h2 class="h_type"><span>TOP 종목</span></h2>
# <ul class="tab_area sise_top1">
# <li class="tab1"><a class="is_active" href="#" onclick="clickcr(this, 'spe.sale', '', '', event);return false;"><span>거래상위</span></a></li>
# <li class="tab2"><a href="#" onclick="clickcr(this, 'spe.ceiling', '', '', event);return false;"><span>상승</span></a></li>
# <li class="tab3"><a href="#" onclick="clickcr(this, 'spe.bottom', '', '', event);return false;"><span>하락</span></a></li>
# <li class="tab4"><a href="#" onclick="clickcr(this, 'spe.value', '', '', event);return false;"><span>시가총액 상위</span></a></li>
# </ul>
# <div class="group_type is_active">
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems1">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>1,916</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 34</td>
# <td>
# <em class="up">
# 				+1.81%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=478390" onclick="clickcr(this, 'spe.slist', '478390', '2', event);">KB제29호스팩</a></th>
# <td>2,015</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 15</td>
# <td>
# <em class="up">
# 				+0.75%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006340" onclick="clickcr(this, 'spe.slist', '006340', '3', event);">대원전선</a></th>
# <td>3,755</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 300</td>
# <td>
# <em class="up">
# 				+8.68%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=147830" onclick="clickcr(this, 'spe.slist', '147830', '4', event);">제룡산업</a></th>
# <td>9,830</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,100</td>
# <td>
# <em class="up">
# 				+27.17%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=152550" onclick="clickcr(this, 'spe.slist', '152550', '5', event);">한국ANKOR유전</a></th>
# <td>462</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 51</td>
# <td>
# <em class="down">
# 				-9.94%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=251340" onclick="clickcr(this, 'spe.slist', '251340', '6', event);">KODEX 코스닥150선물인버스</a></th>
# <td>3,535</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 5</td>
# <td>
# <em class="up">
# 				+0.14%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=198440" onclick="clickcr(this, 'spe.slist', '198440', '7', event);">고려시멘트</a></th>
# <td>2,360</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 60</td>
# <td>
# <em class="up">
# 				+2.61%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=118000" onclick="clickcr(this, 'spe.slist', '118000', '8', event);">에스메디</a></th>
# <td>528</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 22</td>
# <td>
# <em class="down">
# 				-4.00%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=900300" onclick="clickcr(this, 'spe.slist', '900300', '9', event);">오가닉티코스메틱</a></th>
# <td>121</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 2</td>
# <td>
# <em class="down">
# 				-1.63%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=114800" onclick="clickcr(this, 'spe.slist', '114800', '10', event);">KODEX 인버스</a></th>
# <td>4,045</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 45</td>
# <td>
# <em class="up">
# 				+1.13%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=025560" onclick="clickcr(this, 'spe.slist', '025560', '11', event);">미래산업</a></th>
# <td>2,360</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 345</td>
# <td>
# <em class="up">
# 				+17.12%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=159910" onclick="clickcr(this, 'spe.slist', '159910', '12', event);">스킨앤스킨</a></th>
# <td>904</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 27</td>
# <td>
# <em class="up">
# 				+3.08%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=001250" onclick="clickcr(this, 'spe.slist', '001250', '13', event);">GS글로벌</a></th>
# <td>3,210</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 740</td>
# <td>
# <em class="up">
# 				+29.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=023160" onclick="clickcr(this, 'spe.slist', '023160', '14', event);">태광</a></th>
# <td>13,750</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 350</td>
# <td>
# <em class="up">
# 				+2.61%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=005930" onclick="clickcr(this, 'spe.slist', '005930', '15', event);">삼성전자</a></th>
# <td>80,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 1,600</td>
# <td>
# <em class="down">
# 				-1.96%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_quant.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">거래상위 더보기</span></em></a>
# </div>
# <div class="group_type">
# <table class="tbl_home">
# <caption>상승 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems2">
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=001250" onclick="clickcr(this, 'spe.clist', '001250', '1', event);">GS글로벌</a></th>
# <td>3,210</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 740 </td>
# <td>
# <em class="up">
# 				+29.96%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=090370" onclick="clickcr(this, 'spe.clist', '090370', '2', event);">메타랩스</a></th>
# <td>2,120</td>
# <td><em class="bu_p bu_pup2"><span class="blind">상한가</span></em> 486 </td>
# <td>
# <em class="up">
# 				+29.74%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=147830" onclick="clickcr(this, 'spe.clist', '147830', '3', event);">제룡산업</a></th>
# <td>9,830</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,100 </td>
# <td>
# <em class="up">
# 				+27.17%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=078930" onclick="clickcr(this, 'spe.clist', '078930', '4', event);">GS</a></th>
# <td>53,900</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 9,300 </td>
# <td>
# <em class="up">
# 				+20.85%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=200130" onclick="clickcr(this, 'spe.clist', '200130', '5', event);">콜마비앤에이치</a></th>
# <td>18,510</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,890 </td>
# <td>
# <em class="up">
# 				+18.50%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=033790" onclick="clickcr(this, 'spe.clist', '033790', '6', event);">스카이문스테크놀로지</a></th>
# <td>10,720</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,670 </td>
# <td>
# <em class="up">
# 				+18.45%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=033100" onclick="clickcr(this, 'spe.clist', '033100', '7', event);">제룡전기</a></th>
# <td>84,500</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 12,400 </td>
# <td>
# <em class="up">
# 				+17.20%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=025560" onclick="clickcr(this, 'spe.clist', '025560', '8', event);">미래산업</a></th>
# <td>2,360</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 345 </td>
# <td>
# <em class="up">
# 				+17.12%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=453450" onclick="clickcr(this, 'spe.clist', '453450', '9', event);">그리드위즈</a></th>
# <td>47,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 6,700 </td>
# <td>
# <em class="up">
# 				+16.63%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=006345" onclick="clickcr(this, 'spe.clist', '006345', '10', event);">대원전선우</a></th>
# <td>5,620</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 790 </td>
# <td>
# <em class="up">
# 				+16.36%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=024720" onclick="clickcr(this, 'spe.clist', '024720', '11', event);">콜마홀딩스</a></th>
# <td>9,870</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 1,310 </td>
# <td>
# <em class="up">
# 				+15.30%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=089980" onclick="clickcr(this, 'spe.clist', '089980', '12', event);">상아프론테크</a></th>
# <td>27,600</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,400 </td>
# <td>
# <em class="up">
# 				+14.05%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=086710" onclick="clickcr(this, 'spe.clist', '086710', '13', event);">선진뷰티사이언스</a></th>
# <td>21,650</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 2,630 </td>
# <td>
# <em class="up">
# 				+13.83%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=005390" onclick="clickcr(this, 'spe.clist', '005390', '14', event);">신성통상</a></th>
# <td>2,295</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 265 </td>
# <td>
# <em class="up">
# 				+13.05%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=054620" onclick="clickcr(this, 'spe.clist', '054620', '15', event);">APS</a></th>
# <td>7,680</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 820 </td>
# <td>
# <em class="up">
# 				+11.95%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_rise.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">상승 더보기</span></em></a>
# </div>
# <div class="group_type">
# <table class="tbl_home">
# <caption>하락 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems3">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=357880" onclick="clickcr(this, 'spe.blist', '357880', '1', event);">비트나인</a></th>
# <td>2,700</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -795</td>
# <td>
# <em class="down">
# 				-22.75%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=003075" onclick="clickcr(this, 'spe.blist', '003075', '2', event);">코오롱글로벌우</a></th>
# <td>25,350</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -7,400</td>
# <td>
# <em class="down">
# 				-22.60%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=405000" onclick="clickcr(this, 'spe.blist', '405000', '3', event);">플라즈맵</a></th>
# <td>2,530</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -555</td>
# <td>
# <em class="down">
# 				-17.99%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=004545" onclick="clickcr(this, 'spe.blist', '004545', '4', event);">깨끗한나라우</a></th>
# <td>15,280</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -3,110</td>
# <td>
# <em class="down">
# 				-16.91%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=004540" onclick="clickcr(this, 'spe.blist', '004540', '5', event);">깨끗한나라</a></th>
# <td>2,690</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -435</td>
# <td>
# <em class="down">
# 				-13.92%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=007460" onclick="clickcr(this, 'spe.blist', '007460', '6', event);">에이프로젠</a></th>
# <td>1,055</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -154</td>
# <td>
# <em class="down">
# 				-12.74%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=109670" onclick="clickcr(this, 'spe.blist', '109670', '7', event);">씨싸이트</a></th>
# <td>24,700</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -3,600</td>
# <td>
# <em class="down">
# 				-12.72%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=069920" onclick="clickcr(this, 'spe.blist', '069920', '8', event);">아이에스이커머스</a></th>
# <td>2,400</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -290</td>
# <td>
# <em class="down">
# 				-10.78%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=003070" onclick="clickcr(this, 'spe.blist', '003070', '9', event);">코오롱글로벌</a></th>
# <td>14,090</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,650</td>
# <td>
# <em class="down">
# 				-10.48%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=321820" onclick="clickcr(this, 'spe.blist', '321820', '10', event);">아티스트유나이티드</a></th>
# <td>12,910</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,460</td>
# <td>
# <em class="down">
# 				-10.16%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=152550" onclick="clickcr(this, 'spe.blist', '152550', '11', event);">한국ANKOR유전</a></th>
# <td>462</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -51</td>
# <td>
# <em class="down">
# 				-9.94%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=092040" onclick="clickcr(this, 'spe.blist', '092040', '12', event);">아미코젠</a></th>
# <td>7,220</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -770</td>
# <td>
# <em class="down">
# 				-9.64%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=299030" onclick="clickcr(this, 'spe.blist', '299030', '13', event);">하나기술</a></th>
# <td>50,700</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -5,300</td>
# <td>
# <em class="down">
# 				-9.46%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=407400" onclick="clickcr(this, 'spe.blist', '407400', '14', event);">꿈비</a></th>
# <td>9,700</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -1,000</td>
# <td>
# <em class="down">
# 				-9.35%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=101170" onclick="clickcr(this, 'spe.blist', '101170', '15', event);">우림피티에스</a></th>
# <td>7,300</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> -750</td>
# <td>
# <em class="down">
# 				-9.32%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_fall.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">하락 더보기</span></em></a>
# </div>
# <div class="group_type">
# <table class="tbl_home">
# <caption>시가총액 상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems4">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=005930" onclick="clickcr(this, 'spe.vlist', '005930', '1', event);">삼성전자</a></th>
# <td>80,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 1,600</td>
# <td>
# <em class="down">
# 				-1.96%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=000660" onclick="clickcr(this, 'spe.vlist', '000660', '2', event);">SK하이닉스</a></th>
# <td>234,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 3,500</td>
# <td>
# <em class="down">
# 				-1.47%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=373220" onclick="clickcr(this, 'spe.vlist', '373220', '3', event);">LG에너지솔루션</a></th>
# <td>333,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 7,000</td>
# <td>
# <em class="down">
# 				-2.06%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=005380" onclick="clickcr(this, 'spe.vlist', '005380', '4', event);">현대차</a></th>
# <td>280,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 5,500</td>
# <td>
# <em class="down">
# 				-1.93%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=207940" onclick="clickcr(this, 'spe.vlist', '207940', '5', event);">삼성바이오로직스</a></th>
# <td>750,000</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 3,000</td>
# <td>
# <em class="up">
# 				+0.40%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=005935" onclick="clickcr(this, 'spe.vlist', '005935', '6', event);">삼성전자우</a></th>
# <td>63,700</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 800</td>
# <td>
# <em class="down">
# 				-1.24%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=000270" onclick="clickcr(this, 'spe.vlist', '000270', '7', event);">기아</a></th>
# <td>127,900</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 2,700</td>
# <td>
# <em class="down">
# 				-2.07%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=068270" onclick="clickcr(this, 'spe.vlist', '068270', '8', event);">셀트리온</a></th>
# <td>177,100</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 3,000</td>
# <td>
# <em class="down">
# 				-1.67%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=105560" onclick="clickcr(this, 'spe.vlist', '105560', '9', event);">KB금융</a></th>
# <td>78,600</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 2,200</td>
# <td>
# <em class="down">
# 				-2.72%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=005490" onclick="clickcr(this, 'spe.vlist', '005490', '10', event);">POSCO홀딩스</a></th>
# <td>366,500</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 4,500</td>
# <td>
# <em class="down">
# 				-1.21%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=035420" onclick="clickcr(this, 'spe.vlist', '035420', '11', event);">NAVER</a></th>
# <td>167,600</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 400</td>
# <td>
# <em class="up">
# 				+0.24%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=006400" onclick="clickcr(this, 'spe.vlist', '006400', '12', event);">삼성SDI</a></th>
# <td>389,000</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 3,000</td>
# <td>
# <em class="down">
# 				-0.77%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=051910" onclick="clickcr(this, 'spe.vlist', '051910', '13', event);">LG화학</a></th>
# <td>355,500</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 6,000</td>
# <td>
# <em class="down">
# 				-1.66%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=055550" onclick="clickcr(this, 'spe.vlist', '055550', '14', event);">신한지주</a></th>
# <td>47,600</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 50</td>
# <td>
# <em class="down">
# 				-0.10%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=028260" onclick="clickcr(this, 'spe.vlist', '028260', '15', event);">삼성물산</a></th>
# <td>135,300</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 200</td>
# <td>
# <em class="up">
# 				+0.15%
# 				</em>
# </td>
# </tr>
# </tbody>
# </table>
# <a class="btn_more" href="/sise/sise_market_sum.naver" onclick="clickcr(this, 'spe.more', '', '', event);"><em class="btn_more4"><span class="blind">시가총액 상위 더보기</span></em></a>
# </div>
# </div>
# </div>
# <div class="section2">
# <div class="section_stock_market">
# <div class="group_heading">
# <h2 class="h_market"><span>오늘의 증시</span></h2>
# <div class="ly_realtime">
# <span class="btn_realtime" href="#">
# </span>
# <span id="time">
#
#
#
#
# 		                                    	2024.06.21<span>장마감</span>
# </span>
# </div>
# </div>
# <div class="section_stock">
# <div class="kospi_area group_quot quot_opn" style="height:269px">
# <div class="heading_area">
# <h4 class="h_opn"><a class="_stock_section" href="/sise/sise_index.naver?code=KOSPI" onclick="clickcr(this, 'tsc*k.title', '', '', event);" title="코스피지수 상세보기"><em><span class="blind">코스피</span></em></a></h4>
# <a href="/sise/sise_index.naver?code=KOSPI" onclick="clickcr(this, 'tsc*k.title', '', '', event);" title="코스피지수 상세보기">
# <span class="num_quot dn">
# <span class="num">2,784.26</span>
# <span class="num2">23.37</span>
# <span class="num3"><span class="blind">-</span>0.83<span class="per">%</span></span>
# <span class="blind">하락</span>
# </span>
# </a>
# <span class="clse_bg"></span>
# </div>
# <div class="chart_area">
# <p class="blind">코스피 시세 차트</p>
# <a href="/sise/sise_index.naver?code=KOSPI" onclick="clickcr(this, 'tsc*k.chart', '', '', event);" title="코스피지수 상세보기"><img alt="코스피지수 상세보기" height="127" src="https://ssl.pstatic.net/imgfinance/chart/main/KOSPI.png?sidcode=1719029281437" width="301"/></a>
# </div>
# <div class="dsc_area">
# <dl class="dl">
# <dt><a href="/sise/sise_trans_style.naver?sosok=01" onclick="clickcr(this, 'tsc*k.private', '', '', event);" title="투자자별 매매 동향 상세보기">개인</a></dt>
# <dd class="up"><a href="/sise/sise_trans_style.naver?sosok=01" onclick="clickcr(this, 'tsc*k.private', '', '', event);">+3,791</a><span class="blind">억원</span></dd>
# <dt><a href="/sise/sise_trans_style.naver?sosok=01" onclick="clickcr(this, 'tsc*k.foreign', '', '', event);" title="투자자별 매매 동향 상세보기">외국인</a></dt>
# <dd class="dn"><a href="/sise/sise_trans_style.naver?sosok=01" onclick="clickcr(this, 'tsc*k.foreign', '', '', event);">-3,403</a><span class="blind">억원</span></dd>
# <dt><a href="/sise/sise_trans_style.naver?sosok=01" onclick="clickcr(this, 'tsc*k.institutional', '', '', event);" title="투자자별 매매 동향 상세보기">기관</a></dt>
# <dd class="dn"><a href="/sise/sise_trans_style.naver?sosok=01" onclick="clickcr(this, 'tsc*k.institutional', '', '', event);">-280</a><span class="blind">억원</span></dd>
# </dl>
# <dl class="dl2">
# <dt class="blind">상한종목수</dt>
# <dd class="dd"><a href="/sise/sise_upper.naver" onclick="clickcr(this, 'tsc*k.ceiling', '', '', event);" title="상한종목 상세보기">2</a></dd>
# <dt class="blind">상승종목수</dt>
# <dd class="dd2"><a href="/sise/sise_rise.naver?sosok=0" onclick="clickcr(this, 'tsc*k.rise', '', '', event);" title="상승종목 상세보기">297</a></dd>
# <dt class="blind">보합종목수</dt>
# <dd class="dd3"><a href="/sise/sise_steady.naver?sosok=0" onclick="clickcr(this, 'tsc*k.steady', '', '', event);" title="보합종목 상세보기">53</a></dd>
# <dt class="blind">하락종목수</dt>
# <dd class="dd4"><a href="/sise/sise_fall.naver?sosok=0" onclick="clickcr(this, 'tsc*k.drop', '', '', event);" title="하락종목 상세보기">581</a></dd>
# <dt class="blind">하한종목수</dt>
# <dd class="dd5"><a href="/sise/sise_lower.naver" onclick="clickcr(this, 'tsc*k.floor', '', '', event);" title="하한종목 상세보기">0</a></dd>
# </dl>
# </div>
# </div>
# <div class="kosdaq_area group_quot" style="height:40px">
# <div class="heading_area">
# <h4><a class="_stock_section" href="/sise/sise_index.naver?code=KOSDAQ" onclick="clickcr(this, 'tsc*q.title', '', '', event);" title="코스닥지수 상세보기"><em><span class="blind">코스닥</span></em></a></h4>
# <a href="/sise/sise_index.naver?code=KOSDAQ" onclick="clickcr(this, 'tsc*q.title', '', '', event);" title="코스닥지수 상세보기">
# <span class="num_quot dn">
# <span class="num">852.67</span>
# <span class="num2">4.84</span>
# <span class="num3"><span class="blind">-</span>0.56<span class="per">%</span></span>
# <span class="blind">하락</span>
# </span>
# </a>
# <span class="clse_bg"></span>
# </div>
# <div class="chart_area">
# <p class="blind">코스닥 시세 차트</p>
# <a href="/sise/sise_index.naver?code=KOSDAQ" onclick="clickcr(this, 'tsc*q.chart', '', '', event);" title="코스닥지수 상세보기"><img alt="코스닥지수 상세보기" height="127" src="https://ssl.pstatic.net/imgfinance/chart/main/KOSDAQ.png?sidcode=1719029281439" width="301"/></a>
# </div>
# <div class="dsc_area">
# <dl class="dl">
# <dt><a href="/sise/sise_trans_style.naver?sosok=02" onclick="clickcr(this, 'tsc*q.private', '', '', event);" title="투자자별 매매 동향 상세보기">개인</a></dt>
# <dd class="up"><a href="/sise/sise_trans_style.naver?sosok=02" onclick="clickcr(this, 'tsc*q.private', '', '', event);">+374</a><span class="blind">억원</span></dd>
# <dt><a href="/sise/sise_trans_style.naver?sosok=02" onclick="clickcr(this, 'tsc*q.foreign', '', '', event);" title="투자자별 매매 동향 상세보기">외국인</a></dt>
# <dd class="up"><a href="/sise/sise_trans_style.naver?sosok=02" onclick="clickcr(this, 'tsc*q.foreign', '', '', event);">+958</a><span class="blind">억원</span></dd>
# <dt><a href="/sise/sise_trans_style.naver?sosok=02" onclick="clickcr(this, 'tsc*q.institutional', '', '', event);" title="투자자별 매매 동향 상세보기">기관</a></dt>
# <dd class="dn"><a href="/sise/sise_trans_style.naver?sosok=02" onclick="clickcr(this, 'tsc*q.institutional', '', '', event);">-1,223</a><span class="blind">억원</span></dd>
# </dl>
# <dl class="dl2">
# <dt class="blind">상한종목수</dt>
# <dd class="dd"><a href="/sise/sise_upper.naver" onclick="clickcr(this, 'tsc*q.ceiling', '', '', event);" title="상한종목 상세보기">0</a></dd>
# <dt class="blind">상승종목수</dt>
# <dd class="dd2"><a href="/sise/sise_rise.naver?sosok=1" onclick="clickcr(this, 'tsc*q.rise', '', '', event);" title="상승종목 상세보기">370</a></dd>
# <dt class="blind">보합종목수</dt>
# <dd class="dd3"><a href="/sise/sise_steady.naver?sosok=1" onclick="clickcr(this, 'tsc*q.steady', '', '', event);" title="보합종목 상세보기">82</a></dd>
# <dt class="blind">하락종목수</dt>
# <dd class="dd4"><a href="/sise/sise_fall.naver?sosok=1" onclick="clickcr(this, 'tsc*q.drop', '', '', event);" title="하락종목 상세보기">1200</a></dd>
# <dt class="blind">하한종목수</dt>
# <dd class="dd5"><a href="/sise/sise_lower.naver" onclick="clickcr(this, 'tsc*q.floor', '', '', event);" title="하한종목 상세보기">0</a></dd>
# </dl>
# </div>
# </div>
# <div class="kospi200_area group_quot" style="height:40px">
# <div class="heading_area">
# <h4><a class="_stock_section" href="/sise/sise_index.naver?code=KPI200" onclick="clickcr(this, 'tsc*f.title', '', '', event);" title="코스피200지수 상세보기"><em><span class="blind">코스피200</span></em></a></h4>
# <a href="/sise/sise_index.naver?code=KPI200" onclick="clickcr(this,'tsc*o.title','','',event);" title="코스피200지수 상세보기">
# <span class="num_quot dn">
# <span class="num">380.88</span>
# <span class="num2">3.90</span>
# <span class="num3"><span class="blind">-</span>1.01<span class="per">%</span></span>
# <span class="blind">하락</span>
# </span>
# </a>
# <span class="clse_bg"></span>
# </div>
# <div class="chart_area">
# <p class="blind">코스피200 시세 차트</p>
# <a href="/sise/sise_index.naver?code=KPI200" onclick="clickcr(this,'tsc*o.chart','','',event);" title="코스피200지수 상세보기"><img alt="코스피200지수 상세보기" height="127" src="https://ssl.pstatic.net/imgfinance/chart/main/KPI200.png?sidcode=1719029281440" width="301"/></a>
# </div>
# <div class="dsc_area dsc_area2">
# <dl class="dl">
# <dt>개인</dt>
# <dd class="up">+4,268<span class="blind">억원</span></dd>
# <dt>외국인</dt>
# <dd class="dn">-3,719<span class="blind">억원</span></dd>
# <dt>기관</dt>
# <dd class="dn">-447<span class="blind">억원</span></dd>
# </dl>
# </div>
# <div class="basis_area">
# <dl>
# ...
# 	if (oUpdateAjax) {
# 		oUpdateAjax.abort();
# 		oUpdateAjax = null;
# 	}
#
# 	informationTimer = window.clearInterval(informationTimer);
# }
#
# var doUpdateInformation = function() {
# 	var sApiUrl = "/main/mainSummary.naver";
#
# 	oUpdateAjax = jindo.$Ajax(sApiUrl, {
# 		type : "jsonp",
# 		jsonp_charset : "utf-8",
# 		onload : function(oRes) {
# 			if(oRes != null && oRes.readyState() == 4) {
# 				var result = oRes.json().message.result;
# 				if(result != null) {
# 					var todayIndexDealTrendList = result.todayIndexDealTrendList; // 투자매매동향
# 					var todayIndexItemList = result.todayIndexItemList; // 등락종목 개수
# 					var kospiTrendProgram = result.kospiTrendProgram; // 프로그램
# 					var groupTopList = result.groupTopList; // 업종상위
# 					var themeTopList = result.themeTopList; // 테마상위
# 					var topItems = result.topItems; // TOP종목 (거래상위, 상한, 하한, 시가총액상위)
# 					var searchList = result.searchList; // 인기 검색 종목
#
# 					// 오늘의 증시 코스피, 코스닥 투자매매동향 등락종목 개수
# 					jindo.$A(jindo.$$(".dsc_area")).forEach(function(value, index) {
# 						if ( index < 2 ) {
# 							var todayIndexDealTrend = todayIndexDealTrendList[index];
# 							var todayIndexItem = todayIndexItemList[index];
# 							var todayIndexDealTrendLink = new Array("/sise/sise_trans_style.naver?sosok=01", "/sise/sise_trans_style.naver?sosok=02");
#
# 							var oTemplate = jindo.$Template("todayIndexItemTemplate");
# 							var values = jindo.$H(getDealTrendTemplateValues(todayIndexDealTrend));
# 							var tmpMap1 = jindo.$H(getFluctuationTemplateValues(todayIndexItem));
# 							var tmpMap2 = jindo.$H(getIndexItemLinkTemplateValues(todayIndexDealTrendLink, index));
#
# 							tmpMap1.forEach(function(v, k, o) {
# 								values.add(k, v);
# 							});
#
# 							tmpMap2.forEach(function(v, k, o) {
# 								values.add(k, v);
# 							});
#
# 							jindo.$Element(value).html(oTemplate.process(values.$value()));
# 						}
# 					}, this);
#
# 					// 오늘의 증시 코스피200 투자매매동향
# 					jindo.$Element(jindo.$$.getSingle(".dsc_area2")).html(jindo.$Template("todayKpi200Template").process(getDealTrendTemplateValues(todayIndexDealTrendList[2])));
#
# 					// 오늘의 증시 코스피200 프로그램
# 					var trendProgram = new TrendProgram(kospiTrendProgram);
# 					var kospiDifferenceReal = trendProgram.getDifferenceReal();
# 					var kospiBiDifferenceReal = trendProgram.getBiDifferenceReal();
# 					var kospiTotalReal = trendProgram.getTotalReal()
#
# 					var kospiProgramClass = "dd2 " + setUpDnClass(kospiTotalReal);
#
# 					kospiTotalReal = changeNumberFormat(Math.round(kospiTotalReal/100000000));
# 					kospiTotalReal = (kospiBiDifferenceReal + kospiDifferenceReal > 0) ? "+" + kospiTotalReal : "" + kospiTotalReal;
#
# 					var elKospiProgram = jindo.$Element(jindo.$$.getSingle("#_kospiProgram"));
# 					elKospiProgram.className(kospiProgramClass);
#
# 					var sHtml = "";
# 					sHtml = "<a href='/sise/sise_program.naver?sosok=01' onClick='clickcr(this, \"tsc*o.program\", \"\", \"\", event);'>" + kospiTotalReal + "<span>억</span></a>";
# 					elKospiProgram.html(sHtml);
#
# 					// 업종상위
# 					jindo.$A(jindo.$$(".section_top_first .list_rank li")).forEach(function(oElement, index) {
# 						var groupTopItem = groupTopList[index];
# 						var uiCount = index + 1;
# 						var typeNo = groupTopItem.typeNo;
# 						var typeChangeRate = groupTopItem.typeChangeRate;
#
# 						var sHtml = "";
#
# 						sHtml += "<span class='info_num info_num" + uiCount + "'><span class='blind'>" + uiCount + "</span></span><p class='item'><a href='/sise/sise_group_detail.naver?type=upjong&no=" + typeNo + "' onClick='clickcr(this, \"tos.cat" + uiCount + "\", \"upjong_" + typeNo +"\", \"\", event);'>";
# 						sHtml += "<strong>" + cutStringByByte(groupTopItem.typeName, 15, "..") + "</strong></a>";
#
# 						if (typeChangeRate > 0) {
# 							sHtml += "<em class='up'>+" + changeNumberFormat(typeChangeRate.toFixed(2)) + "%</em>";
# 						} else if (typeChangeRate < 0) {
# 							sHtml += "<em class='down'>" + changeNumberFormat(typeChangeRate.toFixed(2)) + "%</em>";
# 						} else {
# 							sHtml += "<em class='steady'>" + changeNumberFormat(typeChangeRate.toFixed(2)) + "%</em>";
# 						}
# 						sHtml += "</p>";
#
# 						for (i = 0; i < groupTopItem.itemList.length; i++) {
# 							var groupTopDetailItem = groupTopItem.itemList[i];
# 							var code = groupTopDetailItem.code;
# 							var changeRate = groupTopDetailItem.changeRate;
#
# 							sHtml += "<p>";
# 							sHtml += "<a href='/item/main.naver?code=" + code + "' onClick='clickcr(this, \"tos.list" + i + "\", \""+ code + "\", \"" + i + "\", event);'>";
# 							sHtml += cutStringByByte(groupTopDetailItem.name, 10, "..") + "</a>";
#
# 							if (changeRate > 0) {
# 								sHtml += "<em class='up'>+" + changeNumberFormat(changeRate.toFixed(2)) + "%</em>";
# 							} else if (changeRate < 0) {
# 								sHtml += "<em class='down'>" + changeNumberFormat(changeRate.toFixed(2)) + "%</em>";
# 							} else {
# 								sHtml += "<em class='steady'>" + changeNumberFormat(changeRate.toFixed(2)) + "%</em>";
# 							}
# 							sHtml += "</p>";
# 						}
#
# 						jindo.$Element(oElement).html(sHtml);
#
# 					}, this);
#
# 					// 테마상위
# 					jindo.$A(jindo.$$(".group_top .list_rank li")).forEach(function(value, index) {
# 						var themeTopItem = themeTopList[index];
# 						var uiCount = index + 1;
#
# 						var sHtml = "";
# 						sHtml += "<span class='info_num info_num" + uiCount + "'><span class='blind'>" + uiCount + "</span></span><p class='item'><a href='/sise/sise_group_detail.naver?type=theme&no=" + themeTopItem.typeNo + "' onClick='clickcr(this, \"pol.type" + uiCount + "\", \"thema_" + themeTopItem.typeNo +"\", \"\", event);'>";
# 						sHtml += "<strong>" + cutStringByByte(themeTopItem.typeName, 15, "..") + "</strong></a>";
#
# 						if (themeTopItem.typeChangeRate > 0) {
# 							sHtml += "<em class='up'>+" + changeNumberFormat(themeTopItem.typeChangeRate.toFixed(2)) + "%</em>";
# 						} else if (themeTopItem.typeChangeRate < 0) {
# 							sHtml += "<em class='down'>" + changeNumberFormat(themeTopItem.typeChangeRate.toFixed(2)) + "%</em>";
# 						} else {
# 							sHtml += "<em class='steady'>" + changeNumberFormat(themeTopItem.typeChangeRate.toFixed(2)) + "%</em>";
# 						}
# 						sHtml += "</p>";
#
# 						for (i = 0; i < themeTopItem.itemList.length; i++) {
# 							var themeTopDetailItem = themeTopItem.itemList[i];
#
# 							sHtml += "<p>";
# 							sHtml += "<a href='/item/main.naver?code=" + themeTopDetailItem.code + "' onClick='clickcr(this, \"tos.list" + i + "\", \""+ themeTopDetailItem.code + "\", \"" + i + "\", event);'>";
# 							sHtml += cutStringByByte(themeTopDetailItem.name, 10, "..") + "</a>";
#
# 							if (themeTopDetailItem.changeRate > 0) {
# 								sHtml += "<em class='up'>+" + changeNumberFormat(themeTopDetailItem.changeRate.toFixed(2)) + "%</em>";
# 							} else if (themeTopDetailItem.changeRate < 0) {
# 								sHtml += "<em class='down'>" + changeNumberFormat(themeTopDetailItem.changeRate.toFixed(2)) + "%</em>";
# 							} else {
# 								sHtml += "<em class='steady'>" + changeNumberFormat(themeTopDetailItem.changeRate.toFixed(2)) + "%</em>";
# 							}
# 							sHtml += "</p>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
#
# 					});
#
# 					// 거래상위
# 					jindo.$A(jindo.$$("#_topItems1 tr")).forEach(function(value, index) {
# 						var topItem = topItems[0][index];
# 						var changeVal = topItem.changeVal;
# 						var changeRate = topItem.changeRate;
# 						var uiCount = index + 1;
# 						var itemcode = topItem.code;
#
# 						setUpDownClass(changeVal, value);
#
# 						var sHtml = "";
# 						sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.slist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 						sHtml += topItem.name + "</a></th>";
# 						sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 						if (changeRate> 0) {
# 							sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 							sHtml += "<td>+" + changeRate.toFixed(2)+ "%</td>";
# 						} else if (changeRate < 0) {
# 							changeRate = changeRate * -1;
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 							sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 						} else {
# 							sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 							sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
# 					});
#
# 					// 상승
# 					jindo.$A(jindo.$$("#_topItems2 tr")).forEach(function(value, index) {
# 						var topItem = topItems[1][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var risefall = topItem.risefall;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
#
# 							if (changeVal != 0) {
# 								if (risefall == '1') {
# 									sHtml += "<td><em class='bu_p bu_pup2'><span class='blind'>상한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								} else {
# 									sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								}
# 								sHtml += "<td>+" + changeRate.toFixed(2)+ "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
# 					// 하락
# 					jindo.$A(jindo.$$("#_topItems3 tr")).forEach(function(value, index) {
# 						var topItem = topItems[2][index];
#
# 						if (topItem) {
# 							var changeVal = topItem.changeVal;
# 							var changeRate = topItem.changeRate;
# 							var risefall = topItem.risefall;
# 							var uiCount = index + 1;
# 							var itemcode = topItem.code;
#
# 							setUpDownClass(changeVal, value);
#
# 							var sHtml = "";
# 							sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.blist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 							sHtml += topItem.name + "</a></th>";
# 							sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 							if (changeVal != 0) {
# 								changeRate = changeRate * -1;
# 								changeVal = changeVal * -1;
# 								if (risefall == '4') {
# 									sHtml += "<td><em class='bu_p bu_pdn2'><span class='blind'>하한가</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								} else {
# 									sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 								}
# 								sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 							} else {
# 								sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 								sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 							}
#
# 							jindo.$Element(value).html(sHtml);
# 						}
# 					});
#
#
# 					// 시가총액 상위
# 					jindo.$A(jindo.$$("#_topItems4 tr")).forEach(function(value, index) {
# 						var topItem = topItems[3][index];
# 						var changeVal = topItem.changeVal;
# 						var changeRate = topItem.changeRate;
# 						var uiCount = index + 1;
# 						var itemcode = topItem.code;
#
# 						setUpDownClass(changeVal, value);
#
# 						var sHtml = "";
# 						sHtml += "<th><a href='/item/main.naver?code=" + itemcode + "' onClick='clickcr(this, \"spe.clist\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 						sHtml += topItem.name + "</a></th>";
# 						sHtml += "<td>" + changeNumberFormat(topItem.nowVal) + "</td>";
#
# 						if (changeRate> 0) {
# 							sHtml += "<td><em class='bu_p bu_pup'><span class='blind'>상승</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 							sHtml += "<td>+" + changeRate.toFixed(2)+ "%</td>";
# 						} else if (changeRate < 0) {
# 							changeRate = changeRate * -1;
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class='bu_p bu_pdn'><span class='blind'>하락</span></em> " + changeNumberFormat(changeVal) + "</td>";
# 							sHtml += "<td>-" + changeRate.toFixed(2) + "%</td>";
# 						} else {
# 							sHtml += "<td><em class='bu_p bu_pn'><span class='blind'>보합</span></em></td>";
# 							sHtml += "<td>" + changeRate.toFixed(2) + "%</td>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
# 					});
#
# 					// 인기 검색 종목
# 					jindo.$A(jindo.$$(".aside_popular tbody tr")).forEach(function(value, index) {
# 						var popularItem = searchList[index];
# 						var uiCount = index + 1;
# 						var changeVal = popularItem.change_val;
# 						var nowVal = popularItem.now_val;
# 						var itemcode = popularItem.itemcode;
#
# 						setUpDownClass(changeVal, value);
#
# 						var sHtml = "";
# 						sHtml += "<th scope=\'row\'><em>" + uiCount + ".</em><a href=\'/item/main.naver?code=" + itemcode + "\' onClick='clickcr(this, \"boa.list\", \"" + itemcode + "\", \"" + uiCount + "\", event);'>";
# 						sHtml += cutStringByByte(popularItem.itemname, 12, "..") + "</a></th>";
# 						sHtml += "<td>" + changeNumberFormat(nowVal) + "</td>";
#
# 						if (popularItem.risefall == 1) {
# 							sHtml += "<td><em class=\'bu_p bu_pup2\'><span class=\'blind\'>상한가</span></em><span class=\'tah p11 red02\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else if (popularItem.risefall == 2) {
# 							sHtml += "<td><em class=\'bu_p bu_pup'><span class=\'blind\'>상승</span></em><span class=\'tah p11 red02\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else if (popularItem.risefall == 3) {
# 							sHtml += "<td><span class=\'tah p11\'> 0 </span></td>";
# 						} else if (popularItem.risefall == 4) {
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class=\'bu_p bu_pdn2\'><span class=\'blind\'>하한가</span></em><span class=\'tah p11 nv01\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						} else{
# 							changeVal = changeVal * -1;
# 							sHtml += "<td><em class=\'bu_p bu_pdn'\><span class=\'blind\'>하락</span></em><span class=\'tah p11 nv01\'> " + changeNumberFormat(changeVal) + " </span></td>";
# 						}
#
# 						jindo.$Element(value).html(sHtml);
#
# 					});
#
# 					startInformationTimer();
# 				}
# 			}
# 		},
# 		timeout : 2,
# 		ontimeout : function() {
# 			startInformationTimer();
# 		},
# 		async : true
# 	});
# 	oUpdateAjax.request();
# }
#
# function getIndexItemLinkTemplateValues(todayIndexDealTrendLink, index) {
# 	values = {
# 			_todayIndexDealTrendLink : todayIndexDealTrendLink[index],
# 			_todayIndexItemUpperLink : "/sise/sise_upper.naver?sosok=" + index,
# 			_todayIndexItemRiseLink : "/sise/sise_rise.naver?sosok=" + index,
# 			_todayIndexItemSteadyLink : "/sise/sise_steady.naver?sosok=" + index,
# 			_todayIndexItemFallLink : "/sise/sise_fall.naver?sosok=" + index,
# 			_todayIndexItemLowerLink : "/sise/sise_lower.naver?sosok=" + index
# 	};
#
# 	return values;
# }
#
# // up, down, same 클래스 생성 기능
# function setUpDownClass(sChangeVal, eValue) {
# 	if (sChangeVal > 0) {
# 		jindo.$Element(eValue).className("up");
# 	} else if (sChangeVal < 0) {
# 		jindo.$Element(eValue).className("down");
# 	} else {
# 		jindo.$Element(eValue).className("same");
# 	}
# }
#
# function setUpDnClass(value){
# 	var className = "";
# 	if (value > 0){
# 		className = "up";
# 	} else if(value < 0){
# 		className = "dn";
# 	}
#
# 	return className;
# }
#
# function mainPageDomReadyFn() {
# 	startInformationTimer();
# 	Polling.init();
# }
#
# function togglePannel(layerId) {
#     var elTargetLayer = jindo.$Element(jindo.$$.getSingle("#" + layerId));
#
#     if (elTargetLayer != null) {
#         if (elTargetLayer.visible()) {
#             hidePannel(layerId);
#         } else {
#             showPannel(layerId);
#         }
#     }
# }
#
# function showPannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='block';
# }
#
# function hidePannel(layerId){
# 	var layer = jindo.$(layerId);
# 	layer.style.display='none';
# }
#
# // 1분 리플레시, 실시간 시세 폴링, 이미지 리플레시
# jindo.$Fn(mainPageDomReadyFn).attach(document, "domready");
#
# </script>
# </body>
# </html>

# %%
srclist = soup.select('.section_strategy')
print(srclist)
# Out:
# [<div class="section_strategy">
# <h2 class="h_strategy"><span>주요뉴스</span></h2>
# <ul>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=243&amp;article_id=0000060980" onclick="clickcr(this, 'tdn.list', '243_0000060980', '0', event);">국내 증시 대신 해외 주식 택하는 개미들... 해외주식 보관액 역대 최대 기록</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=011&amp;article_id=0004356599" onclick="clickcr(this, 'tdn.list', '011_0004356599', '1', event);">'AI 황제株' 엔비디아 이틀 연속 3%대 하락…무슨 일?</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=421&amp;article_id=0007617224" onclick="clickcr(this, 'tdn.list', '421_0007617224', '2', event);">연중 최고치 기록한 '빚투'…돈 빌려 대왕고래·이혼 테마주 산 개미들</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=008&amp;article_id=0005054029" onclick="clickcr(this, 'tdn.list', '008_0005054029', '3', event);">증시 출사표 백종원 '더본'…풀무원·동원 vs 교촌, 어느 곳과 닮았나?</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=009&amp;article_id=0005322999" onclick="clickcr(this, 'tdn.list', '009_0005322999', '4', event);">“돈도 안되는 4등, 왜 하겠어”…이통사 또 만들겠다는 정부, 헛다리 짚었다 [나기자의 데이터로 세상읽기]</a></span>
# </li>
# <li>
# <span><a href="/news/news_read.naver?mode=mainnews&amp;office_id=018&amp;article_id=0005770929" onclick="clickcr(this, 'tdn.list', '018_0005770929', '5', event);">‘시누이 지분 매도’ 마저 소화해버린 ‘불닭 열풍’[증시 핫피플]</a></span>
# </li>
# </ul>
# <a class="btn_more" href="/news/mainnews.naver" onclick="clickcr(this, 'tdn.more', '', '', event);"><em class="btn_more4"><span class="blind">주요뉴스 더보기</span></em></a>
# </div>]

# %%
srclist = soup.select('.section_strategy li a')
print(srclist)
# Out:
# [<a href="/news/news_read.naver?mode=mainnews&amp;office_id=243&amp;article_id=0000060980" onclick="clickcr(this, 'tdn.list', '243_0000060980', '0', event);">국내 증시 대신 해외 주식 택하는 개미들... 해외주식 보관액 역대 최대 기록</a>, <a href="/news/news_read.naver?mode=mainnews&amp;office_id=011&amp;article_id=0004356599" onclick="clickcr(this, 'tdn.list', '011_0004356599', '1', event);">'AI 황제株' 엔비디아 이틀 연속 3%대 하락…무슨 일?</a>, <a href="/news/news_read.naver?mode=mainnews&amp;office_id=421&amp;article_id=0007617224" onclick="clickcr(this, 'tdn.list', '421_0007617224', '2', event);">연중 최고치 기록한 '빚투'…돈 빌려 대왕고래·이혼 테마주 산 개미들</a>, <a href="/news/news_read.naver?mode=mainnews&amp;office_id=008&amp;article_id=0005054029" onclick="clickcr(this, 'tdn.list', '008_0005054029', '3', event);">증시 출사표 백종원 '더본'…풀무원·동원 vs 교촌, 어느 곳과 닮았나?</a>, <a href="/news/news_read.naver?mode=mainnews&amp;office_id=009&amp;article_id=0005322999" onclick="clickcr(this, 'tdn.list', '009_0005322999', '4', event);">“돈도 안되는 4등, 왜 하겠어”…이통사 또 만들겠다는 정부, 헛다리 짚었다 [나기자의 데이터로 세상읽기]</a>, <a href="/news/news_read.naver?mode=mainnews&amp;office_id=018&amp;article_id=0005770929" onclick="clickcr(this, 'tdn.list', '018_0005770929', '5', event);">‘시누이 지분 매도’ 마저 소화해버린 ‘불닭 열풍’[증시 핫피플]</a>]

# %%
for a in srclist:
    print(a.text)
# Out:
# 국내 증시 대신 해외 주식 택하는 개미들... 해외주식 보관액 역대 최대 기록
# 'AI 황제株' 엔비디아 이틀 연속 3%대 하락…무슨 일?
# 연중 최고치 기록한 '빚투'…돈 빌려 대왕고래·이혼 테마주 산 개미들
# 증시 출사표 백종원 '더본'…풀무원·동원 vs 교촌, 어느 곳과 닮았나?
# “돈도 안되는 4등, 왜 하겠어”…이통사 또 만들겠다는 정부, 헛다리 짚었다 [나기자의 데이터로 세상읽기]
# ‘시누이 지분 매도’ 마저 소화해버린 ‘불닭 열풍’[증시 핫피플]

# %%
url = srclist[0]['href']
PATH + url
# Out:
# 'https://finance.naver.com//news/news_read.naver?mode=mainnews&office_id=243&article_id=0000060980'

# %%
from urllib.parse import urljoin

# %%
urljoin(PATH, url)
# Out:
# 'https://finance.naver.com/news/news_read.naver?mode=mainnews&office_id=243&article_id=0000060980'

# %%
news_title = []
news_url = []
for a in srclist:
    title = a.text
    url = urljoin(PATH, a['href'])
    news_title.append(title)
    news_url.append(url)

# %%
import pandas as pd

# %%
df = pd.DataFrame({'제목':news_title, '주소':news_url})
df
# Out:
#                                                   제목  \
# 0        국내 증시 대신 해외 주식 택하는 개미들... 해외주식 보관액 역대 최대 기록
# 1                   'AI 황제株' 엔비디아 이틀 연속 3%대 하락…무슨 일?
# 2             연중 최고치 기록한 '빚투'…돈 빌려 대왕고래·이혼 테마주 산 개미들
# 3           증시 출사표 백종원 '더본'…풀무원·동원 vs 교촌, 어느 곳과 닮았나?
# 4  “돈도 안되는 4등, 왜 하겠어”…이통사 또 만들겠다는 정부, 헛다리 짚었다 [나기...
# 5               ‘시누이 지분 매도’ 마저 소화해버린 ‘불닭 열풍’[증시 핫피플]
#
#                                                   주소
# 0  https://finance.naver.com/news/news_read.naver...
# 1  https://finance.naver.com/news/news_read.naver...
# 2  https://finance.naver.com/news/news_read.naver...
# 3  https://finance.naver.com/news/news_read.naver...
# 4  https://finance.naver.com/news/news_read.naver...
# 5  https://finance.naver.com/news/news_read.naver...

# %%
df.to_excel('output/0622_review.xlsx', index=False)

# %%
#네이버 검색결과 수집하기

# %%
import requests
from bs4 import BeautifulSoup

# %%
PATH = 'https://search.naver.com/search.naver'

# %%
keyword = input('검색어를 입력하세요')
# Out:
# 검색어를 입력하세요 ai

# %%
resp = requests.get(PATH, params = {'query':keyword})
resp
# Out:
# <Response [200]>

# %%
src = resp.text
soup = BeautifulSoup (src , 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="ai : 네이버 검색" property="og:title"/> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'ai'의 네이버 검색 결과입니다." property="og:description"/> <meta content="'ai'의 네이버 검색 결과입니다." lang="ko" name="description"/> <title>ai : 네이버 검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"/><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_240620.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_240620.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_240530.css" rel="stylesheet" type="text/css"/><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=''; mid.style.visibility='visible'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden('"+id+"')",100); } function hidden (id) { var mid=document.getElementById(id); mid.style.display='none'; mid.style.visibility='hidden'; } fun ...
# <script crossorigin="anonymous" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/js/231108/power_link_for_you_responsive_pc.js?o=search"></script>
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl && _elAdIndLayerPl.visible()) {
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elAdIndLayerPl = _elDscNcautionPl.next().next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         _elAdIndLayerPl.hide();
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
# <script>
#     (function () {
#       var defaultFavicon = "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png";
#       naver.common.imageLazyLoader.onError(
#               naver.common.LazySrc.Handler.create({
#                 "power-link-favicon-error": function ($img) {
#                   $img.attr("src", defaultFavicon);
#                 }
#               })
#       );
#     })();
#   </script>
# <link href="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/240415/css/nx_powerlink.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet" type="text/css"/>
# <div class="sc_new ad_section section _pl_section bg_type_v2">
# <div class="api_subject_bx">
# <div class="mod_title_area">
# <div class="title_wrap">
# <h2 class="title">파워링크</h2>
# <span class="sub">
# <span class="title_text">
# <em class="dsc_ncaution_quotation">‘</em>
# <strong class="dsc_ncaution_keyword">ai</strong>
# <em class="dsc_ncaution_quotation">’</em>관련 광고입니다.
#             </span>
# </span>
# <a class="api_ad_link" href="javascript:void(0);" onclick="if(adInfoShowPl(this)) goOtherCR(this, 'a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u='+urlencode(this.href));" role="button">
# <i class="spnew api_ico_alert">이 광고가 표시된 이유</i>
# </a>
# </div>
# <div class="title_sub">
# <a class="sub_link" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="ly_api_info" style="display: none;">
# <p class="dsc">이 광고는 사이트검색광고(파워링크)로, 검색어와 광고의 연관도, 광고주의 입찰가 등에 의해 광고 노출 여부와 순위가 결정됩니다.</p>
# <div class="btn_area">
# <a class="link" href="https://help.naver.com/service/5626/contents/1419">도움말</a>
# </div>
# <button class="btn_close" onclick="adInfoHidePl();" type="button">
# <i class="spnew ico_close">정보확인 레이어 닫기</i>
# </button>
# </div>
# </div>
# <div class="nad_area" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=...">
# <ul class="lst_type">
# <li class="lst type_more type_subtitle ext_place" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=5gpvVb2mNPft0kspa9Qv8////w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=1&amp;i=nad-a001-01-000000291802482&amp;d='+urlencode('http://www.globit.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.globit.kr%2Fimages2%2Ffavicon-16x16.png&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_talktalk" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 톡톡</span>
# <a class="ly_ad _tooltip" href="//talk.naver.com/intro" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.talktalk&amp;r=1&amp;i=nad-a001-01-000000291802482&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버톡톡으로 상담이 가능한 사이트입니다.</p>
# <p class="ly_ad_go"><strong>톡톡</strong> 서비스 보기<span class="sp_nad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="site" href="https://adcr.naver.com/adcr?x=5gpvVb2mNPft0kspa9Qv8////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000291802482&amp;d='+urlencode('http://www.globit.kr')+'&amp;u='+urlencode(this.href));" target="_blank">글로빛논문컨설팅</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=5gpvVb2mNPft0kspa9Qv8////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000291802482&amp;d='+urlencode('http://www.globit.kr')+'&amp;u='+urlencode(this.href));" target="_blank">globit.kr</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=5gpvVb2mNPft0kspa9Qv8////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000291802482&amp;d=' + urlencode('http://www.globit.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">논문브랜드8년연속1위 글로빛</span><span class="lnk_tit">논문작성관련 저작권등록 업체</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=5gpvVb2mNPft0kspa9Qv8////w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=1&amp;i=nad-a001-01-000000291802482&amp;d=' + urlencode('http://www.globit.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">논문컨설팅 8년연속브랜드1위, 업계최초 논뮨작성 특허출원, sci급 최우수지도교수</a>
# </div>
# <div class="place_image">
# <div class="thumb_list flicking-camera" id="place_flicking">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=dDr9mo3S6hQQlMJ0d5FuI////w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221025_3%2F1666688397941wq16M_JPEG%2F_SI_0241-2.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=dDr9mo3S6hQQlMJ0d5FuI////w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20231211_223%2F1702265000519rNwba_PNG%2F%25BC%25BA%25B1%25D5%25B0%25FC%25B4%25EB%25C6%25AF%25B0%25AD-1.png&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=dDr9mo3S6hQQlMJ0d5FuI////w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20231211_201%2F1702265000998mkDvg_PNG%2F%25C8%25AD%25B8%25E9_%25C4%25B8%25C3%25B3_2023-11-02_101106.png&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=dDr9mo3S6hQQlMJ0d5FuI////w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20230406_30%2F1680761734240eem4B_JPEG%2FKakaoTalk_20210709_170729167_01.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=dDr9mo3S6hQQlMJ0d5FuI////w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20231211_60%2F1702268876821qqPxo_PNG%2F%25BC%25AD%25BF%25EF%25BD%25C3%25B8%25B3%25B4%25EB_%25B0%25AD%25C0%25C7_%25C4%25B8%25C3%25C4.png&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=dDr9mo3S6hQQlMJ0d5FuI////w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20221025_193%2F1666688389443Sv0QS_JPEG%2F%25B0%25ED%25B0%25B4%25C0%25CC%25BD%25C5%25B7%25DA%25C7%25CF%25B4%25C2%25BA%25EA%25B7%25A3%25B5%25E5%25B4%25EB%25BB%25F3_2022_%25C6%25CB%25BE%25F7_%25B1%25DB%25B7%25CE%25BA%25FB.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=dDr9mo3S6hQQlMJ0d5FuI////w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20231207_237%2F1701927742854HtH1W_JPEG%2F20231204180224822_0001.jpg&amp;type=a380"/>
# </a><a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=dDr9mo3S6hQQlMJ0d5FuI////w==..." target="_black">
# <img alt="플레이스 이미지" class="img_thumb" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fldb-phinf.pstatic.net%2F20230406_131%2F1680761734414a3jXV_JPEG%2FKakaoTalk_20210715_133342083_17.jpg&amp;type=a380"/>
# <span class="img_thumb_more"></span>
# </a>
# </div>
# <button class="prev_button" id="_place_prev_button" style="display:none">
# <span class="blind">이전으로 이동</span>
# </button>
# <button class="next_button" id="_place_next_button" style="display:none">
# <span class="blind">다음으로 이동</span>
# </button>
# </div>
# <a class="place_info" href="https://adcr.naver.com/adcr?x=dDr9mo3S6hQQlMJ0d5FuI////w==..." onclick="return goOtherCR(this,'a=pwl_nop.place&amp;r=1&amp;i=nad-a001-01-000000291802482&amp;d='+urlencode('http://www.globit.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <div class="keyword_area">
# <span class="item">논문컨설팅</span><span class="item">석사논문컨설팅</span><span class="item">박사논문컨설팅</span><span class="item">논문통계</span><span class="item">논문교정</span>
# </div>
# <div class="etc_area">
# <span class="item">방문자리뷰 1</span>
# </div>
# </a>
# </div>
# </li>
# <li class="lst type_more ext_link type_img" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=xLvzutZ4q+QVBJf4gcxhgv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=2&amp;i=nad-a001-01-000000306827986&amp;d='+urlencode('https://a.sktelecom.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMzA5MjZfNzYg/MDAxNjk1NjkyNjU3MDE4.zXSTRgwJ4eWXnHCTuPr0iDEO_Vw-PATm3FeknmWGJGcg.kUCSVAO6Im4a6UDzKWBN4FLsvCR3VBe2oXB7BcXizMIg.PNG/550866-ba87751b-2afb-418b-a87d-af5b2787c798.png?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=oma/JMzU3lq1BWnvAoHmrf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=2&amp;i=nad-a001-01-000000306827986&amp;d='+urlencode('https://a.sktelecom.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fcdn.sktapollo.com%2Fdevelopers%2Fpoc%2Fapp.apollo.agent%2Fstatic%2Fhome%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="site" href="https://adcr.naver.com/adcr?x=oma/JMzU3lq1BWnvAoHmrf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000306827986&amp;d='+urlencode('https://a.sktelecom.com')+'&amp;u='+urlencode(this.href));" target="_blank">에이닷</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=oma/JMzU3lq1BWnvAoHmrf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000306827986&amp;d='+urlencode('https://a.sktelecom.com')+'&amp;u='+urlencode(this.href));" target="_blank">a.sktelecom.com</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=oma/JMzU3lq1BWnvAoHmrf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000306827986&amp;d=' + urlencode('https://a.sktelecom.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">나만의 AI 개인비서 에이닷</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=oma/JMzU3lq1BWnvAoHmrf///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=2&amp;i=nad-a001-01-000000306827986&amp;d=' + urlencode('https://a.sktelecom.com') + '&amp;u='+ urlencode(this.href));" target="_blank">궁금할 때, 물음표를 해결해주는 내 손안의 똑똑한 지식문답 서비스, 에이닷!</a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=wwrfWkLaAH/XcAgo4fjLxP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=2&amp;i=nad-a001-01-000000306827986&amp;d='+urlencode('https://a.sktelecom.com')+'&amp;u='+urlencode(this.href));" target="_blank">서비스 소개</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=FuUWMZyoSyZXLj9vOSKl3f///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=2&amp;i=nad-a001-01-000000306827986&amp;d='+urlencode('https://a.sktelecom.com')+'&amp;u='+urlencode(this.href));" target="_blank">다운로드</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=t2EP0hH9LpFj2cszwyfYZP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=2&amp;i=nad-a001-01-000000306827986&amp;d='+urlencode('https://a.sktelecom.com')+'&amp;u='+urlencode(this.href));" target="_blank">모션프로필</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_link type_img" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=Fo5zaxjW1FGAMHeaRHo/rf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000307726239&amp;d='+urlencode('https://futuring.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyNDA2MTNfMjQ2/MDAxNzE4MjQzNDk1NzY1.U4j9mqC2GYSKathX4g80tYPjm6aZMrdW3z4JBRD_wfAg.kNkM6q4U95AHuMg9l0-N2o_PYh_UWEOI77k1cwwNTEgg.PNG/1106679-6c515af8-a8b0-4eaf-9050-6170f8e7b0d7.png?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=8M3u8WBfIf2Eq7u5u4IDUf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=3&amp;i=nad-a001-01-000000307726239&amp;d='+urlencode('https://futuring.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Ffuturing.co.kr%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=8M3u8WBfIf2Eq7u5u4IDUf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000307726239&amp;d='+urlencode('https://futuring.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">futuring.co.kr</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=8M3u8WBfIf2Eq7u5u4IDUf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000307726239&amp;d=' + urlencode('https://futuring.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">AI개발용 GPU서버 기획전</span><span class="lnk_tit">구매 시 푸짐한 상품권 혜택</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=8M3u8WBfIf2Eq7u5u4IDUf///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=3&amp;i=nad-a001-01-000000307726239&amp;d=' + urlencode('https://futuring.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">벨아이앤에스X퓨처링 기획전, 최신 GPU서버 구매 시 100만원 상당 상품권 혜택</a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=mSyboUhf9z2MgRdvucD5s////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=3&amp;i=nad-a001-01-000000307726239&amp;d='+urlencode('https://futuring.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">푸짐한 혜택</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=qRw+Ft6cG7WFw03kYvEPxP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=3&amp;i=nad-a001-01-000000307726239&amp;d='+urlencode('https://futuring.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">서버 라인업</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=Jxlmuva8vd/1oGsVv7uoCv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=3&amp;i=nad-a001-01-000000307726239&amp;d='+urlencode('https://futuring.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">특별한 이유</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=U8Kiek/2MH8OVJixadwJYf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=3&amp;i=nad-a001-01-000000307726239&amp;d='+urlencode('https://futuring.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">알잘딱 비법</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_link type_img" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=CxaYYogco9etjEwb7fYgC////w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=4&amp;i=nad-a001-01-000000252292592&amp;d='+urlencode('http://in4ucloud.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMzA3MDVfMTUy/MDAxNjg4NTM0MDM1NzYz.P20a33tRYwYsyQscogY4k1IXUtPh7Ko8KNvWS416ewsg.HGJXhZLZL4S845Jr6iMpMypUweuFimkQUtiwlIi7Qzkg.PNG/438519-07c0cd6c-b764-416c-a956-be1c5c1d07e1.png?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=+T1VOpKptsZO1+UTh/pMEf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=4&amp;i=nad-a001-01-000000252292592&amp;d='+urlencode('http://in4ucloud.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.in4ucloud.com%2Fwp-content%2Fuploads%2F2022%2F10%2Ffavicon.png&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="site" href="https://adcr.naver.com/adcr?x=+T1VOpKptsZO1+UTh/pMEf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000252292592&amp;d='+urlencode('http://in4ucloud.com')+'&amp;u='+urlencode(this.href));" target="_blank">인포유홈페이지</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=+T1VOpKptsZO1+UTh/pMEf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000252292592&amp;d='+urlencode('http://in4ucloud.com')+'&amp;u='+urlencode(this.href));" target="_blank">in4ucloud.com</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=+T1VOpKptsZO1+UTh/pMEf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000252292592&amp;d=' + urlencode('http://in4ucloud.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">챗GPT 활용은 인포유에서</span><span class="lnk_tit">Microsoft 공식파트너</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=+T1VOpKptsZO1+UTh/pMEf///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=4&amp;i=nad-a001-01-000000252292592&amp;d=' + urlencode('http://in4ucloud.com') + '&amp;u='+ urlencode(this.href));" target="_blank">기업을 위한 사내 ChatGPT 환경 구축, 다양한 Open<strong class="hl">AI</strong> 솔루션 보유</a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=18racCsM3WWhvQ7cBHHPuv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=4&amp;i=nad-a001-01-000000252292592&amp;d='+urlencode('http://in4ucloud.com')+'&amp;u='+urlencode(this.href));" target="_blank">오픈AI소개</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=Tk88Dvu3nqdCqb8jxKgaqv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=4&amp;i=nad-a001-01-000000252292592&amp;d='+urlencode('http://in4ucloud.com')+'&amp;u='+urlencode(this.href));" target="_blank">고객사례</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=h5R3bjZipgOgTRCJj/MtKv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=4&amp;i=nad-a001-01-000000252292592&amp;d='+urlencode('http://in4ucloud.com')+'&amp;u='+urlencode(this.href));" target="_blank">문의하기</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=PRNrKKnPs+jGFsx7cXvTWv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=5&amp;i=nad-a001-01-000000279296905&amp;d='+urlencode('https://nbcamp.spartacodingclub.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMzA1MjZfNTcg/MDAxNjg1MDk1OTEyNzE2.0AWUSv-r27mU5PedcvwLurxYXDArtth3f0OVlD2GPbMg.Hn2s-HOwsBP1AFAIgBnKBPhw5IjV406S3tnjuQqK3EYg.JPEG/1739570-d63594e4-9f8b-479d-84f5-46cdf62c1e01.jpg?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=E4Xf3BpRR8vKkc73dDykQf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=5&amp;i=nad-a001-01-000000279296905&amp;d='+urlencode('https://nbcamp.spartacodingclub.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fnbcamp.spartacodingclub.kr%2Ffavicon.png&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="site" href="https://adcr.naver.com/adcr?x=E4Xf3BpRR8vKkc73dDykQf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000279296905&amp;d='+urlencode('https://nbcamp.spartacodingclub.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">스파르타내일배움캠프</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=E4Xf3BpRR8vKkc73dDykQf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000279296905&amp;d='+urlencode('https://nbcamp.spartacodingclub.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">nbcamp.spartacodingclub.kr/</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=E4Xf3BpRR8vKkc73dDykQf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000279296905&amp;d=' + urlencode('https://nbcamp.spartacodingclub.kr/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">내일배움캠프 AI 웹개발자</span><span class="lnk_tit">100%무료 개발자 취업과정</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=E4Xf3BpRR8vKkc73dDykQf///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=5&amp;i=nad-a001-01-000000279296905&amp;d=' + urlencode('https://nbcamp.spartacodingclub.kr/') + '&amp;u='+ urlencode(this.href));" target="_blank">집에서 파이썬 코테+<strong class="hl">AI</strong> 웹개발, 전액 국비지원, 월31만원 별도 훈련지원금까지!</a>
# </div>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img" num="5" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=mNp1CmHIfQ0Ajv6tgwdeB////w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=6&amp;i=nad-a001-01-000000305093002&amp;d='+urlencode('https://www.polarisoffice.com/ko/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyNDA2MDRfODUg/MDAxNzE3NDgzNDI4NDYz.Db5KV6GPoVIdOyVfKvbYmcR8o6B9CdlNfDPIAofhWp4g.YjKQ6yq-5qgqm7UGvezSDLY3BFEbydnwtgErr4YVz20g.PNG/1738373-2841ffe9-42b3-4854-9d91-f860ccd521a5.png?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=M4l7slZbEG7HQMu8ILJwB////w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=6&amp;i=nad-a001-01-000000305093002&amp;d='+urlencode('https://www.polarisoffice.com/ko/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fpolink-static-contents.polarisoffice.com%2Fweb%2Fassets%2Fimg%2Ffavicon-32x32.png&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="site" href="https://adcr.naver.com/adcr?x=M4l7slZbEG7HQMu8ILJwB////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000305093002&amp;d='+urlencode('https://www.polarisoffice.com/ko/')+'&amp;u='+urlencode(this.href));" target="_blank">폴라리스오피스</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=M4l7slZbEG7HQMu8ILJwB////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000305093002&amp;d='+urlencode('https://www.polarisoffice.com/ko/')+'&amp;u='+urlencode(this.href));" target="_blank">polarisoffice.com/ko/</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=M4l7slZbEG7HQMu8ILJwB////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000305093002&amp;d=' + urlencode('https://www.polarisoffice.com/ko/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">AI, 폴라리스오피스!</span><span class="lnk_tit">한 번 구매하면 평생소장!</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=M4l7slZbEG7HQMu8ILJwB////w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=6&amp;i=nad-a001-01-000000305093002&amp;d=' + urlencode('https://www.polarisoffice.com/ko/') + '&amp;u='+ urlencode(this.href));" target="_blank">인터넷이 없어도 사용가능한 On-Device <strong class="hl">AI</strong> 솔루션!</a>
# </div>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img" num="6" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=ikdU0iQard0H/QKRaFZtav///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=7&amp;i=nad-a001-01-000000305328955&amp;d='+urlencode('http://www.kmong.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMjAzMDRfMTUz/MDAxNjQ2MzIyOTc4NDEz.8e4FmQH_99TSoN9I2WIGEfD9DR_ht3TRcWwIUtE-oVUg.dc1nH4bvaX74-VLlW81D1bHgymQ7AN-4bwXnFHyMtHcg.PNG/663520-e4a1ee51-9763-4f78-8e57-877566742015.png?type=f160_160"/>
# </a>
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=8TlOWub67OqFnGlQZqtn4////w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=7&amp;i=nad-a001-01-000000305328955&amp;d='+urlencode('http://www.kmong.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fkmong.com%2Ffavicon%2Ffavicon-32x32.png&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=7&amp;i=nad-a001-01-000000305328955&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="site" href="https://adcr.naver.com/adcr?x=8TlOWub67OqFnGlQZqtn4////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000305328955&amp;d='+urlencode('http://www.kmong.com')+'&amp;u='+urlencode(this.href));" target="_blank">크몽</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=8TlOWub67OqFnGlQZqtn4////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000305328955&amp;d='+urlencode('http://www.kmong.com')+'&amp;u='+urlencode(this.href));" target="_blank">kmong.com</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=8TlOWub67OqFnGlQZqtn4////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000305328955&amp;d=' + urlencode('http://www.kmong.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">AI 전문가, 크몽</span><span class="lnk_tit">인공지능 필요할 땐, 크몽</span><span class="lnk_tit"><strong class="hl">AI</strong> 시대에서 살아남는 방법</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=8TlOWub67OqFnGlQZqtn4////w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=7&amp;i=nad-a001-01-000000305328955&amp;d=' + urlencode('http://www.kmong.com') + '&amp;u='+ urlencode(this.href));" target="_blank">전세계가 주목하는 <strong class="hl">AI</strong>! 크몽의 <strong class="hl">AI</strong> 서비스 총집합, 놓치지 마세요! <strong class="hl">AI</strong> 인공지능/ 챗GPT/ 달리/ 미드저니</a>
# </div>
# </div>
# </li>
# <li class="lst" num="7" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=VEVIMeRYssB3klmM4QGSSf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=8&amp;i=nad-a001-01-000000226406450&amp;d='+urlencode('http://sn.ezenac.co.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fsn.ezenac.co.kr%2Fimages%2Fcommon%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="site" href="https://adcr.naver.com/adcr?x=VEVIMeRYssB3klmM4QGSSf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000226406450&amp;d='+urlencode('http://sn.ezenac.co.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">이젠아카데미분당</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=VEVIMeRYssB3klmM4QGSSf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000226406450&amp;d='+urlencode('http://sn.ezenac.co.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">sn.ezenac.co.kr/</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=VEVIMeRYssB3klmM4QGSSf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000226406450&amp;d=' + urlencode('http://sn.ezenac.co.kr/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">이젠아카데미컴퓨터학원 분당</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=VEVIMeRYssB3klmM4QGSSf///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=8&amp;i=nad-a001-01-000000226406450&amp;d=' + urlencode('http://sn.ezenac.co.kr/') + '&amp;u='+ urlencode(this.href));" target="_blank">국비지원 전액무료, 프로젝트기반 빅데이터 <strong class="hl">AI</strong>솔루션 개발자 육성과정!,<strong class="hl">AI</strong></a>
# </div>
# </div>
# </li>
# <li class="lst" num="8" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=QYK3DZtT46v+5kl2554Fh////w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=9&amp;i=nad-a001-01-000000308107920&amp;d='+urlencode('http://www.iscu.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=http%3A%2F%2Fwww.iscu.ac.kr%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="site" href="https://adcr.naver.com/adcr?x=QYK3DZtT46v+5kl2554Fh////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000308107920&amp;d='+urlencode('http://www.iscu.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">서울사이버대학교</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=QYK3DZtT46v+5kl2554Fh////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000308107920&amp;d='+urlencode('http://www.iscu.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">iscu.ac.kr</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=QYK3DZtT46v+5kl2554Fh////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=9&amp;i=nad-a001-01-000000308107920&amp;d=' + urlencode('http://www.iscu.ac.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">서울사이버대 드론로봇융합학과</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=QYK3DZtT46v+5kl2554Fh////w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=9&amp;i=nad-a001-01-000000308107920&amp;d=' + urlencode('http://www.iscu.ac.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">드론로봇산업, 국방드론봇, 드론자격증. 신편입생모집 ~7/11</a>
# </div>
# </div>
# </li>
# <li class="lst" num="9" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <div class="url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=DyOeoVTTZEOb4tcS7kxS3v///w==..." onclick="return goOtherCR(this,'a=pwl_nop.favicon&amp;r=10&amp;i=nad-a001-01-000000299439909&amp;d='+urlencode('https://www.lloydk.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fwww.lloydk.co.kr%2Fassets%2Fimages%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <span class="icon_nad_mark">광고</span>
# <a class="site" href="https://adcr.naver.com/adcr?x=DyOeoVTTZEOb4tcS7kxS3v///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000299439909&amp;d='+urlencode('https://www.lloydk.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">로이드케이</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=DyOeoVTTZEOb4tcS7kxS3v///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000299439909&amp;d='+urlencode('https://www.lloydk.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">lloydk.co.kr</a>
# </span>
# </div>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=DyOeoVTTZEOb4tcS7kxS3v///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000299439909&amp;d=' + urlencode('https://www.lloydk.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">엘라스틱 엘리트 파트너</span>
# </a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=DyOeoVTTZEOb4tcS7kxS3v///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=10&amp;i=nad-a001-01-000000299439909&amp;d=' + urlencode('https://www.lloydk.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">엘라스틱서치를 벡터DB로 활용하는 Gen<strong class="hl">AI</strong> 기반의 RAG구성 검색솔루션, DO!</a>
# </div>
# </div>
# </li>
# </ul>
# <div class="mod_more_wrap">
# <a class="group_more" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=ai&amp;referenceId=iFC20wqo1awsshqH9yCssssssm4-374680" onclick="return goOtherCR(this, 'a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u='+urlencode(this.href));" target="_blank">
# <span class="etc">더보기<i class="spnew ico_arr"></i></span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">
#     (function () {
#       var createPlaceImageConveyer = function () {
#         var prev = document.getElementById("_place_prev_button");
#         var next = document.getElementById("_place_next_button");
#         if (prev == null || next == null) {
#           return;
#         }
#         prev.style.display = "none";
#         var require = window.require.config({
#           context: "impression_neo_place_extension",
#           paths: {
#             "egjsConveyer": "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220822/js/egjs-conveyer.min.k253dc24"
#           }
#         });
#         require(["egjsConveyer"], function (egjsConveyer) {
#           var conveyer = new egjsConveyer("#place_flicking", {autoInit: false, preventClickOnDrag: true});
#
#
#           conveyer.subscribe("isReachStart", function (isReachStart) {
#             prev.style.display = isReachStart ? "none" : "block";
#           });
#
#           conveyer.subscribe("isReachEnd", function (isReachEnd) {
#             next.style.display = isReachEnd ? "none" : "block";
#           });
#           conveyer.init();
#
#           if (!conveyer.isReachEnd) {
#             next.style.display = "block";
#           }
#
#           prev.addEventListener("click", function () {
#             conveyer.scrollIntoView("start", {
#               align: "end",
#               duration: 500,
#               excludeStand: true,
#             });
#           });
#           next.addEventListener("click", function () {
#             conveyer.scrollIntoView("end", {
#               align: "start",
#               duration: 500,
#               excludeStand: true,
#             });
#           });
#         });
#       };
#       nhn.common.load_js(null, createPlaceImageConveyer, true, 150);
#     })();
#   </script>
# <div class="sc_new ad_section section" data-responsive-json='{"aq":0,"ssc":"tab.nx.all","apiUrl":"https://external-api.impression-neo.naver.com/api/v1/powerLinkForYou/responsive/ads/search","requestId":"iFC20wqo1awsshqH9yCssssssm4-374680","query":"ai","channel":"naver.search.pc.pl.responsive","sm":null,"adCreativeIds":["nad-a001-01-000000291802482","nad-a001-01-000000306827986","nad-a001-01-000000307726239","nad-a001-01-000000252292592","nad-a001-01-000000279296905","nad-a001-01-000000305093002","nad-a001-01-000000305328955","nad-a001-01-000000226406450","nad-a001-01-000000308107920","nad-a001-01-000000299439909","nad-a001-01-000000292297458","nad-a001-01-000000284375713","nad-a001-01-000000291439599","nad-a001-01-000000184503012","nad-a001-01-000000297929368"]}' id="_power_link_together_section" style="display: none;">
# <div id="responsive_root"></div>
# <div class="lst_type_v2" id="map_layer" style="display: none;">
# <div class="lst">
# <div class="ly_map _preview_layer" id="_preview_layer" style="top: 0px !important;">
# <h4 class="sp_ad_map m_tit">위치 미리보기</h4>
# <div class="map_area" height="312" id="map" width="375">
# <div id="map" style="position: relative; overflow: hidden; background: url('https://ssl.pstatic.net/static/maps/mantle/1x/pattern_1.png') 0px 0px repeat transparent; width: 375px; height: 312px;"></div>
# <span class="bd"><span class="bd_top"></span><span class="bd_rgt"></span><span class="bd_btm"></span><span class="bd_lft"></span></span>
# </div>
# <div class="tit_area">
# <div class="tit_sec">
# <h4 class="tit">
# <a class="txt" href="" id="preview_headline" onclick="" target="_blank"></a>
# <a class="sp_ad_map ico_find_road" href="" id="preview_find_map" onclick="" target="_blank">길찾기</a>
# </h4>
# <div class="m_url">
# <a class="txt" href="" id="preview_display_url" onclick="" target="_blank"></a>
# </div>
# </div>
# <div class="info_sec">
# <div class="address">
# <p class="txt" id="preveiw_number_address"></p>
# <p class="txt">
# <span class="sp_ad_map ico_road_name"><span class="blind">도로명 주소</span></span> <span id="preview_road_address"></span>
# </p>
# </div>
# <div class="dsc"></div>
# </div>
# </div>
# <a class="sp_ad_mall btn_clse" href="javascript:;" id="map_btn_clse">닫기</a>
# </div>
# </div>
# </div>
# </div>
# ...
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fcwstatic.asiae.co.kr%2Fevent%2Fe.asia_tablet_ico.png&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=5TyMPqqs2Qv67u9dbzXxnP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=2&amp;i=nad-a001-01-000000284375713&amp;d=' + urlencode('https://e.asiae.co.kr/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">아시아경제 AI</span>
# </a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=5TyMPqqs2Qv67u9dbzXxnP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=2&amp;i=nad-a001-01-000000284375713&amp;d='+urlencode('https://e.asiae.co.kr/')+'&amp;u='+urlencode(this.href));" target="_blank">e.asiae.co.kr/</a>
# </span>
# <span class="icon_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.naverlogin&amp;r=2&amp;i=nad-a001-01-000000284375713&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=5TyMPqqs2Qv67u9dbzXxnP///w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=2&amp;i=nad-a001-01-000000284375713&amp;d=' + urlencode('https://e.asiae.co.kr/') + '&amp;u='+ urlencode(this.href));" target="_blank">IT 직무교육, 공모전 준비, 대기업 취업연계 컨설팅까지 <strong class="hl">AI</strong></a>
# </div>
# </div>
# </li>
# <li class="lst type_biz" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=meFeEbjnq0PmK/rmr+XMDv///w==..." onclick="return goOtherCR(this,'a=biz_nop.favicon&amp;r=13&amp;i=nad-a001-01-000000291439599&amp;d='+urlencode('https://fip.snu.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Ffip.snu.ac.kr%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=meFeEbjnq0PmK/rmr+XMDv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000291439599&amp;d=' + urlencode('https://fip.snu.ac.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">서울대 미래융합기술최고위과정</span>
# </a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=meFeEbjnq0PmK/rmr+XMDv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000291439599&amp;d='+urlencode('https://fip.snu.ac.kr')+'&amp;u='+urlencode(this.href));" target="_blank">fip.snu.ac.kr</a>
# </span>
# <span class="icon_nad_mark">광고</span>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=meFeEbjnq0PmK/rmr+XMDv///w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=3&amp;i=nad-a001-01-000000291439599&amp;d=' + urlencode('https://fip.snu.ac.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">생성형<strong class="hl">AI</strong>, 클라우드 및 메타버스,지능형반도체,뉴모빌리티,양자컴퓨터,미래에너지기술</a>
# </div>
# </div>
# </li>
# <li class="lst type_biz" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=cqp68BViHao/670jVh+wSv///w==..." onclick="return goOtherCR(this,'a=biz_nop.favicon&amp;r=14&amp;i=nad-a001-01-000000184503012&amp;d='+urlencode('https://www.inflearn.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fcdn.inflearn.com%2Fdist%2Ffavicon.ico&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=cqp68BViHao/670jVh+wSv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000184503012&amp;d=' + urlencode('https://www.inflearn.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">AI강의는 인프런에서!</span>
# </a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=cqp68BViHao/670jVh+wSv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000184503012&amp;d='+urlencode('https://www.inflearn.com')+'&amp;u='+urlencode(this.href));" target="_blank">inflearn.com</a>
# </span>
# <span class="icon_nad_mark">광고</span>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=cqp68BViHao/670jVh+wSv///w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=4&amp;i=nad-a001-01-000000184503012&amp;d=' + urlencode('https://www.inflearn.com') + '&amp;u='+ urlencode(this.href));" target="_blank"><strong class="hl">AI</strong>, 핵심기술 <strong class="hl">AI</strong>, 머신러닝부터 딥러닝까지 인프런 데이터사이언스 총 집합!</a>
# </div>
# </div>
# </li>
# <li class="lst type_biz" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <div class="title_url_area">
# <a class="favicon_wrap" href="https://adcr.naver.com/adcr?x=Bj6f8LofQQzg4WgqiH72o////w==..." onclick="return goOtherCR(this,'a=biz_nop.favicon&amp;r=15&amp;i=nad-a001-01-000000297929368&amp;d='+urlencode('http://biz.atalk.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="favicon" class="icon_favicon" data-img-alias="power-link-favicon-error" data-lazysrc="https://search.pstatic.net/sunny?src=http%3A%2F%2Fbiz.atalk.co.kr%2Fsuperboard%2Fdata%2Fsiteconfig%2F2022012404093216429973727756.jpg&amp;type=f30_30_png_expire24" height="16" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png" width="16"/>
# </a>
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=Bj6f8LofQQzg4WgqiH72o////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000297929368&amp;d=' + urlencode('http://biz.atalk.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">AI상담 아톡비즈</span>
# </a>
# <a class="site" href="https://adcr.naver.com/adcr?x=Bj6f8LofQQzg4WgqiH72o////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000297929368&amp;d='+urlencode('http://biz.atalk.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">아톡비즈</a>
# <span class="lnk_url_area">
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=Bj6f8LofQQzg4WgqiH72o////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000297929368&amp;d='+urlencode('http://biz.atalk.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">biz.atalk.co.kr</a>
# </span>
# <span class="icon_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_talktalk" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);">네이버 톡톡</span>
# <a class="ly_ad _tooltip" href="//talk.naver.com/intro" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.talktalk&amp;r=5&amp;i=nad-a001-01-000000297929368&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <span>네이버톡톡으로 상담이 가능한 사이트입니다.</span>
# <span class="ly_ad_go"><strong>톡톡</strong> 서비스 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=Bj6f8LofQQzg4WgqiH72o////w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=5&amp;i=nad-a001-01-000000297929368&amp;d=' + urlencode('http://biz.atalk.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">채팅상담, 고객관리, 전문콜센터, <strong class="hl">AI</strong>CC, 콜백기능등을 컨설팅 받으세요</a>
# </div>
# </div>
# </li>
# </ul>
# <div class="mod_more_wrap">
# <a class="group_more" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=ai&amp;referenceId=iFC20wqo1awsshqH9yCssssssm4-374680" onclick="return goOtherCR(this, 'a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u='+urlencode(this.href));" target="_blank">
# <span class="etc">더보기<i class="spnew ico_arr"></i></span></a>
# </div>
# </div>
# </div>
# </div>
# <div class="_scrollLog" data-slog-id="biz_nop" style="visibility:hidden;height:0px;margin:0 28px"></div><div class="api_sc_page_wrap"><div class="sc_page"><a aria-disabled="true" class="btn_prev" role="button"><i class="spnew api_ico_pg_arr">이전</i></a><div class="sc_page_inner"><a aria-pressed="true" class="btn" href="?nso=&amp;query=ai&amp;sm=tab_pge&amp;where=nexearch" onclick='goOtherCR(this,"a=pag.pag&amp;r=1&amp;i=&amp;u="+urlencode(this.href))' role="button">1</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=2&amp;query=ai&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=2&amp;i=&amp;u="+urlencode(this.href))' role="button">2</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=3&amp;query=ai&amp;sm=tab_pge&amp;start=16&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=3&amp;i=&amp;u="+urlencode(this.href))' role="button">3</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=4&amp;query=ai&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=4&amp;i=&amp;u="+urlencode(this.href))' role="button">4</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=5&amp;query=ai&amp;sm=tab_pge&amp;start=46&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=5&amp;i=&amp;u="+urlencode(this.href))' role="button">5</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=6&amp;query=ai&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=6&amp;i=&amp;u="+urlencode(this.href))' role="button">6</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=7&amp;query=ai&amp;sm=tab_pge&amp;start=76&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=7&amp;i=&amp;u="+urlencode(this.href))' role="button">7</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=8&amp;query=ai&amp;sm=tab_pge&amp;start=91&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=8&amp;i=&amp;u="+urlencode(this.href))' role="button">8</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=9&amp;query=ai&amp;sm=tab_pge&amp;start=106&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=9&amp;i=&amp;u="+urlencode(this.href))' role="button">9</a>
# <a aria-pressed="false" class="btn" href="?nso=&amp;page=10&amp;query=ai&amp;sm=tab_pge&amp;start=121&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=10&amp;i=&amp;u="+urlencode(this.href))' role="button">10</a></div><a aria-disabled="false" class="btn_next" href="?nso=&amp;page=11&amp;query=ai&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&amp;r=11&amp;i=&amp;u="+urlencode(this.href))' role="button"><i class="spnew api_ico_pg_arr">다음</i></a></div></div><div class="_scrollLogEndline" style="visibility:hidden;height:0px"></div></div><div class="sub_pack" id="sub_pack"><section class="sc_new"> <div class="api_subject_bx"> <div class="api_common_banner"> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2309-cue-001&amp;material=&amp;target=https%3A%2F%2Fcue.search.naver.com%2F%3Ffrom%3Dsearch_pc2nd" nocr="" onclick="return goOtherCR(this, 'a=bnr.link1&amp;r=1&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20240415_286/1713170852871jnLfL_PNG/760_31963112_marketing_banner_pc_icon_0_1713170852853.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">AI 검색, 아직 안 써봤다면?</strong> <p class="elss dsc">네이버 Cue: 사전 신청하기</p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2405-clovax-001&amp;material=pro_2&amp;target=https%3A%2F%2Fclova-x.naver.com%2F%3Fdtm_detail%3Dpro_2%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2405-clovax-001" nocr="" onclick="return goOtherCR(this, 'a=bnr.link2&amp;r=2&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20240415_156/1713170852871tl1zF_PNG/760_31963112_marketing_banner_pc_icon_1_1713170852856.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">누가 대신 읽고 요약 좀 해주라</strong> <p class="elss dsc">문서 요약도 CLOVA X</p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2404-shopping-009&amp;material=memjoin&amp;target=https%3A%2F%2Fnid.naver.com%2Fmembership%2Fjoin%3Fdtm_detail%3Dmemjoin%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2404-shopping-009" nocr="" onclick="return goOtherCR(this, 'a=bnr.link3&amp;r=3&amp;i=&amp;u=' + urlencode(this.href));" target="_blank"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20240531_121/1717151836236OE3Fq_PNG/760_31963112_marketing_banner_pc_icon_2_1717151836202.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">네이버플러스 멤버십 3개월 무료</strong> <p class="elss dsc">지금 바로 시작하기</p> </div> </a> <a class="spnew_bf item" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&amp;campaign_id=2405-travel-001&amp;target=https%3A%2F%2Fsearch.naver.com%2Fsearch.naver%3Fmra%3DUlJUX1RJTQ%3D%3D%26where%3Dnexearch%26sm%3Dtop_hty%26fbm%3D0%26ie%3Dutf8%26query%3D%25EA%25B5%25AD%25EB%2582%25B4%25EC%2597%25AC%25EB%25A6%2584%25EC%2597%25AC%25ED%2596%2589%25EC%25A7%2580%26pcode%3Dnaver_pcsearchmktbanner%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2405-travel-001" nocr="" onclick="return goOtherCR(this, 'a=bnr.link4&amp;r=4&amp;i=&amp;u=' + urlencode(this.href));"> <div class="ico_area"><img alt="" class="ico" height="36" src="https://csearch-phinf.pstatic.net/20240616_13/1718543093917kludh_PNG/760_31963112_marketing_banner_pc_icon_3_1718543093903.png" width="36"/></div> <div class="dsc_area"> <strong class="elss tit">산으로 바다로 시원한 여름 여행</strong> <p class="elss dsc">국내 여행지 모아보기</p> </div> </a> </div> </div> </section> <script> var nx_cr_right_area_info = [{"n": "bnr", "r": 1}]; </script></div><div class="ly_dimmed"> ...

# %%
item = soup.select('.news_tit')
print(len(item))
print(item)
# Out:
# 4
# [<a class="news_tit" href="https://www.newsis.com/view/NISX20240624_0002784774" onclick="return goOtherCR(this, 'a=nws_all*h.tit&amp;r=1&amp;i=88000127_000000000000000012625493&amp;g=003.0012625493&amp;u='+urlencode(this.href));" target="_blank" title="카카오톡 AI 프로필 서비스 문 닫는다">카카오톡 <mark>AI</mark> 프로필 서비스 문 닫는다</a>, <a class="news_tit" href="https://weekly.khan.co.kr/khnm.html?mode=view&amp;code=114&amp;artid=202406240600031" onclick="return goOtherCR(this, 'a=nws_all*h.tit&amp;r=4&amp;i=8800006C_000000000000000000047334&amp;g=033.0000047334&amp;u='+urlencode(this.href));" target="_blank" title="혁신인 듯 혁신 아닌 애플 AI, 게임체인저 될까">혁신인 듯 혁신 아닌 애플 <mark>AI</mark>, 게임체인저 될까</a>, <a class="news_tit" href="https://www.hankyung.com/article/2024062479551" onclick="return goOtherCR(this, 'a=nws_all*e.tit&amp;r=7&amp;i=88000107_000000000000000005001130&amp;g=015.0005001130&amp;u='+urlencode(this.href));" target="_blank" title="엠디엠의 실험…시니어 주택에 AI 접목">엠디엠의 실험…시니어 주택에 <mark>AI</mark> 접목</a>, <a class="news_tit" href="https://biz.chosun.com/stock/finance/2024/06/24/XXLJXKB74VH2VND7DX4554JVXA/?utm_source=naver&amp;utm_medium=original&amp;utm_campaign=biz" onclick="return goOtherCR(this, 'a=nws_all*e.tit&amp;r=8&amp;i=88127058_000000000000000000999975&amp;g=366.0000999975&amp;u='+urlencode(this.href));" target="_blank" title="하나은행, 수출환어음매입 업무에 자체 개발 AI 기술 도입">하나은행, 수출환어음매입 업무에 자체 개발 <mark>AI</mark> 기술 도입</a>]

# %%
for a in item:
    print(a.text, a['href'])
# Out:
# 카카오톡 AI 프로필 서비스 문 닫는다 https://www.newsis.com/view/NISX20240624_0002784774
# 혁신인 듯 혁신 아닌 애플 AI, 게임체인저 될까 https://weekly.khan.co.kr/khnm.html?mode=view&code=114&artid=202406240600031
# 엠디엠의 실험…시니어 주택에 AI 접목 https://www.hankyung.com/article/2024062479551
# 하나은행, 수출환어음매입 업무에 자체 개발 AI 기술 도입 https://biz.chosun.com/stock/finance/2024/06/24/XXLJXKB74VH2VND7DX4554JVXA/?utm_source=naver&utm_medium=original&utm_campaign=biz
